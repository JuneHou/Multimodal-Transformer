# %%
# autoreload
# %load_ext autoreload
# %autoreload 2

# %%
import os
import pandas as pd
from tqdm import tqdm

# %%
mimic_iv_notes_parent = "/data/wang/junh/datasets/physionet.org/files/mimic-iv-note/2.2/note"
mimic_iv_path = "/data/wang/junh/datasets/physionet.org/files/mimiciv/2.2"

rad_notes_f_path = os.path.join(mimic_iv_notes_parent, "radiology.csv.gz")
rad_notes_df = pd.read_csv(rad_notes_f_path, low_memory=False)
rad_notes_df['charttime'] = pd.to_datetime(rad_notes_df['charttime'])
rad_notes_df['storetime'] = pd.to_datetime(rad_notes_df['storetime'])

icustays_df = pd.read_csv(os.path.join(mimic_iv_path, "icu", "icustays.csv.gz"), low_memory=False)
icustays_df['intime'] = pd.to_datetime(icustays_df['intime'])
icustays_df['outtime'] = pd.to_datetime(icustays_df['outtime'])

admissions_df = pd.read_csv(os.path.join(mimic_iv_path, "hosp", "admissions.csv.gz"), low_memory=False)
admissions_df['admittime'] = pd.to_datetime(admissions_df['admittime'])
admissions_df['dischtime'] = pd.to_datetime(admissions_df['dischtime'])

# %%
notes_df = pd.read_csv(os.path.join(mimic_iv_notes_parent, "discharge.csv"), low_memory=False)

# %%
notes_df['charttime'] = pd.to_datetime(notes_df['charttime'])
notes_df['storetime'] = pd.to_datetime(notes_df['storetime'])

# %%
print(notes_df.columns)
print("Number of notes: ", len(notes_df))
# Out:
# Index(['note_id', 'subject_id', 'hadm_id', 'note_type', 'note_seq',
#        'charttime', 'storetime', 'text'],
#       dtype='object')
# Number of notes:  331793

# %%
print(rad_notes_df.columns)
print("Number of rad notes: ", len(rad_notes_df))
# Out:
# Index(['note_id', 'subject_id', 'hadm_id', 'note_type', 'note_seq',
#        'charttime', 'storetime', 'text'],
#       dtype='object')
# Number of rad notes:  2321355

# %%
notes_df = pd.read_pickle("/data/wang/junh/datasets/multimodal/preprocessing/clinic_notes_text.pkl")

# %%
rad_notes_df = pd.read_pickle("/data/wang/junh/datasets/multimodal/preprocessing/notes_text.pkl")

# %%
print(notes_df['subject_id'].nunique())
# Out:
# 145914

# %%
print(rad_notes_df['subject_id'].nunique())
# Out:
# 237427

# %%
notes_df = notes_df[(notes_df['subject_id'].notnull())]
notes_df = notes_df[(notes_df['hadm_id'].notnull())]
rad_notes_df = rad_notes_df[(rad_notes_df['subject_id'].notnull())]
rad_notes_df = rad_notes_df[(rad_notes_df['hadm_id'].notnull())]

# %%
merge_notes_df = pd.merge(notes_df, rad_notes_df[['subject_id', 'hadm_id', 'text']], on=['subject_id', 'hadm_id'], how='right')
# Out:
# /data/wang/junh/envs/fuse_env/lib/python3.8/site-packages/pandas/core/reshape/merge.py:916: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   key_col = Index(lvals).where(~mask_left, rvals)

# %%
print(merge_notes_df.columns)
print("Number of merged notes: ", len(merge_notes_df))
# Out:
# Index(['note_id', 'subject_id', 'hadm_id', 'note_type', 'note_seq',
#        'charttime', 'storetime', 'text_x', 'stay_id', 'icu_time_delta',
#        'hosp_time_delta', 'text_y'],
#       dtype='object')
# Number of merged notes:  832140

# %%
merge_notes_df.rename(columns={'text_x': 'clinic_text', 'text_y': 'text'}, inplace=True)

# %%
mm_dir = "/data/wang/junh/datasets/multimodal"
output_dir = os.path.join(mm_dir, "preprocessing")

merge_notes_df.to_pickle(os.path.join(output_dir, "merge_notes_text.pkl"))
print(merge_notes_df.shape)
# Out:
# (832140, 12)

# %%
merge_notes_df
# Out:
#                note_id  subject_id     hadm_id note_type  note_seq  charttime  \
# 0       10000032-DS-21    10000032  22595853.0        DS      21.0 2180-05-07
# 1       10000032-DS-21    10000032  22595853.0        DS      21.0 2180-05-07
# 2       10000032-DS-24    10000032  25742920.0        DS      24.0 2180-08-07
# 3       10000032-DS-24    10000032  25742920.0        DS      24.0 2180-08-07
# 4       10000117-DS-22    10000117  27988844.0        DS      22.0 2183-09-21
# ...                ...         ...         ...       ...       ...        ...
# 832135   19999987-DS-2    19999987  23865745.0        DS       2.0 2145-11-11
# 832136   19999987-DS-2    19999987  23865745.0        DS       2.0 2145-11-11
# 832137   19999987-DS-2    19999987  23865745.0        DS       2.0 2145-11-11
# 832138   19999987-DS-2    19999987  23865745.0        DS       2.0 2145-11-11
# 832139   19999987-DS-2    19999987  23865745.0        DS       2.0 2145-11-11
#
#                  storetime                                        clinic_text  \
# 0      2180-05-09 15:26:00   \nName:  ___                     Unit No:   _...
# 1      2180-05-09 15:26:00   \nName:  ___                     Unit No:   _...
# 2      2180-08-10 05:43:00   \nName:  ___                     Unit No:   _...
# 3      2180-08-10 05:43:00   \nName:  ___                     Unit No:   _...
# 4      2183-09-29 16:23:00   \nName:  ___                 Unit No:   ___\n...
# ...                    ...                                                ...
# 832135 2145-11-11 13:13:00   \nName:  ___                    Unit No:   __...
# 832136 2145-11-11 13:13:00   \nName:  ___                    Unit No:   __...
# 832137 2145-11-11 13:13:00   \nName:  ___                    Unit No:   __...
# 832138 2145-11-11 13:13:00   \nName:  ___                    Unit No:   __...
# 832139 2145-11-11 13:13:00   \nName:  ___                    Unit No:   __...
#
#        stay_id icu_time_delta hosp_time_delta  \
# 0         None           None        1.616667
# 1         None           None        1.616667
# 2         None           None       24.266667
# 3         None           None       24.266667
# 4         None           None       53.833333
# ...        ...            ...             ...
# 832135    None           None      194.366667
# 832136    None           None      194.366667
# 832137    None           None      194.366667
# 832138    None           None      194.366667
# 832139    None           None      194.366667
#
#                                                      text
# 0       EXAMINATION:  LIVER OR GALLBLADDER US (SINGLE ...
# 1       INDICATION:  ___ HCV cirrhosis c/b ascites, hi...
# 2       EXAMINATION:  PARACENTESIS\n\nINDICATION:  ___...
# 3       EXAMINATION:  LIVER OR GALLBLADDER US (SINGLE ...
# 4       EXAMINATION:  HIP NAILING IN OR W/FILMS AND FL...
# ...                                                   ...
# 832135  HISTORY:  ___, with left occipital bleeding.  ...
# 832136  INDICATION:  ___ female intubated for head ble...
# 832137  HISTORY:  ___ woman with left occipital hemorr...
# 832138  PORTABLE CHEST OF ___\n\nCOMPARISON:  ___ radi...
# 832139  DATE OF SERVICE:  ___.\n\nPRE-OPERATIVE DIAGNO...
#
# [832140 rows x 12 columns]

# %%
rad_notes_df
# Out:
#                 note_id  subject_id   hadm_id note_type  note_seq  \
# 0        10000032-RR-14    10000032      None        RR        14
# 1        10000032-RR-15    10000032  22595853        RR        15
# 2        10000032-RR-16    10000032  22595853        RR        16
# 3        10000032-RR-18    10000032      None        RR        18
# 4        10000032-RR-20    10000032      None        RR        20
# ...                 ...         ...       ...       ...       ...
# 2321350  19999987-RR-17    19999987  23865745        RR        17
# 2321351  19999987-RR-18    19999987  23865745        RR        18
# 2321352  19999987-RR-19    19999987  23865745        RR        19
# 2321353  19999987-RR-20    19999987  23865745        RR        20
# 2321354  19999987-RR-21    19999987  23865745        RR        21
#
#                   charttime           storetime  \
# 0       2180-05-06 21:19:00 2180-05-06 23:32:00
# 1       2180-05-06 23:00:00 2180-05-06 23:26:00
# 2       2180-05-07 09:55:00 2180-05-07 11:15:00
# 3       2180-06-03 12:46:00 2180-06-03 14:01:00
# 4       2180-07-08 13:18:00 2180-07-08 14:15:00
# ...                     ...                 ...
# 2321350 2145-11-02 22:37:00 2145-11-03 18:55:00
# 2321351 2145-11-03 04:35:00 2145-11-03 10:46:00
# 2321352 2145-11-03 16:40:00 2145-11-04 08:36:00
# 2321353 2145-11-04 05:10:00 2145-11-04 08:58:00
# 2321354 2145-11-07 15:18:00 2145-11-08 16:44:00
#
#                                                       text   stay_id  \
# 0        EXAMINATION:  CHEST (PA AND LAT)\n\nINDICATION...      None
# 1        EXAMINATION:  LIVER OR GALLBLADDER US (SINGLE ...      None
# 2        INDICATION:  ___ HCV cirrhosis c/b ascites, hi...      None
# 3        EXAMINATION:  Ultrasound-guided paracentesis.\...      None
# 4        EXAMINATION:  Paracentesis\n\nINDICATION:  ___...      None
# ...                                                    ...       ...
# 2321350  HISTORY:  ___, with left occipital bleeding.  ...      None
# 2321351  INDICATION:  ___ female intubated for head ble...  36195440
# 2321352  HISTORY:  ___ woman with left occipital hemorr...  36195440
# 2321353  PORTABLE CHEST OF ___\n\nCOMPARISON:  ___ radi...  36195440
# 2321354  DATE OF SERVICE:  ___.\n\nPRE-OPERATIVE DIAGNO...      None
#
#         icu_time_delta hosp_time_delta
# 0                 None            None
# 1                 None        0.616667
# 2                 None       11.533333
# 3                 None            None
# 4                 None            None
# ...                ...             ...
# 2321350           None        0.983333
# 2321351            5.6            6.95
# 2321352      17.683333       19.033333
# 2321353      30.183333       31.533333
# 2321354           None      113.666667
#
# [2321355 rows x 11 columns]

# %%
notes_df
# Out:
#                note_id  subject_id   hadm_id note_type  note_seq  charttime  \
# 0       10000032-DS-21    10000032  22595853        DS        21 2180-05-07
# 1       10000032-DS-22    10000032  22841357        DS        22 2180-06-27
# 2       10000032-DS-23    10000032  29079034        DS        23 2180-07-25
# 3       10000032-DS-24    10000032  25742920        DS        24 2180-08-07
# 4       10000084-DS-17    10000084  23052089        DS        17 2160-11-25
# ...                ...         ...       ...       ...       ...        ...
# 331788   19999828-DS-6    19999828  29734428        DS         6 2147-08-04
# 331789   19999828-DS-7    19999828  25744818        DS         7 2149-01-18
# 331790  19999840-DS-20    19999840  26071774        DS        20 2164-07-28
# 331791  19999840-DS-21    19999840  21033226        DS        21 2164-09-17
# 331792   19999987-DS-2    19999987  23865745        DS         2 2145-11-11
#
#                  storetime                                               text  \
# 0      2180-05-09 15:26:00   \nName:  ___                     Unit No:   _...
# 1      2180-07-01 10:15:00   \nName:  ___                     Unit No:   _...
# 2      2180-07-25 21:42:00   \nName:  ___                     Unit No:   _...
# 3      2180-08-10 05:43:00   \nName:  ___                     Unit No:   _...
# 4      2160-11-25 15:09:00   \nName:  ___                    Unit No:   __...
# ...                    ...                                                ...
# 331788 2147-08-12 15:36:00   \nName:  ___                   Unit No:   ___...
# 331789 2149-01-19 07:03:00   \nName:  ___                   Unit No:   ___...
# 331790 2164-07-29 14:52:00   \nName:  ___                  Unit No:   ___\...
# 331791 2164-09-18 01:36:00   \nName:  ___                  Unit No:   ___\...
# 331792 2145-11-11 13:13:00   \nName:  ___                    Unit No:   __...
#
#          stay_id icu_time_delta hosp_time_delta
# 0           None           None        1.616667
# 1           None           None            5.55
# 2           None           None       35.416667
# 3           None           None       24.266667
# 4           None           None       94.066667
# ...          ...            ...             ...
# 331788      None           None      391.616667
# 331789      None           None      223.266667
# 331790      None           None           71.55
# 331791  38978960     110.558889      154.216667
# 331792      None           None      194.366667
#
# [331793 rows x 11 columns]

# %%
notes_df['stay_id'].notna().sum()
# Out:
# 11455
