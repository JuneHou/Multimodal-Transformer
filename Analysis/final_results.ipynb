# %%
import json
import pickle
def load_data(file_path):
    """ Load the data from a pickle file. """
    with open(file_path, 'rb') as f:
        return pickle.load(f)

# %% [markdown]
# # KL + MI Subset

# %%
# 4 label 4 mods -- bi-level 0.05
print(load_data("/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_mi/los-48-cxr-notes-ecg/TS_CXR_Text_ECG/TS_48/Atten/f1/result.pkl"))
# Out:
# {'42': {'confusion_matrix': {'test': array([[ 79, 134,  22,   2],
#        [ 60, 192,  65,  31],
#        [  7,  47,  50,  28],
#        [  1,  19,  17,  22]])}, 'classification_report': {'test': '                 precision    recall  f1-score   support\n\n       ≤ 3 days       0.54      0.33      0.41       237\n > 3 & ≤ 7 days       0.49      0.55      0.52       348\n> 7 & ≤ 14 days       0.32      0.38      0.35       132\n      > 14 days       0.27      0.37      0.31        59\n\n       accuracy                           0.44       776\n      macro avg       0.40      0.41      0.40       776\n   weighted avg       0.46      0.44      0.44       776\n'}, 'f1': {'test': 0.3974716892080449}}}

# %%
# 4 label ts ecg txt -- bi-level 0.05
print(load_data("/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_mi/los-48-cxr-notes-ecg/TS_ECG_Text/TS_48/Atten/f1/result.pkl"))
# Out:
# {'42': {'confusion_matrix': {'test': array([[ 64, 146,  26,   1],
#        [ 51, 202,  88,   7],
#        [  8,  39,  74,  11],
#        [  0,  17,  36,   6]])}, 'classification_report': {'test': '                 precision    recall  f1-score   support\n\n       ≤ 3 days       0.52      0.27      0.36       237\n > 3 & ≤ 7 days       0.50      0.58      0.54       348\n> 7 & ≤ 14 days       0.33      0.56      0.42       132\n      > 14 days       0.24      0.10      0.14        59\n\n       accuracy                           0.45       776\n      macro avg       0.40      0.38      0.36       776\n   weighted avg       0.46      0.45      0.43       776\n'}, 'f1': {'test': 0.36284426951113535}}}

# %%
# 4 label ts cxr ecg -- bi-level 0.05
print(load_data("/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_mi/los-48-cxr-notes-ecg/TS_CXR_ECG/TS_48/Atten/f1/result.pkl"))
# Out:
# {'42': {'confusion_matrix': {'test': array([[  2, 233,   2,   0],
#        [  0, 344,   4,   0],
#        [  0, 130,   2,   0],
#        [  0,  57,   2,   0]])}, 'classification_report': {'test': '                 precision    recall  f1-score   support\n\n       ≤ 3 days       1.00      0.01      0.02       237\n > 3 & ≤ 7 days       0.45      0.99      0.62       348\n> 7 & ≤ 14 days       0.20      0.02      0.03       132\n      > 14 days       0.00      0.00      0.00        59\n\n       accuracy                           0.45       776\n      macro avg       0.41      0.25      0.17       776\n   weighted avg       0.54      0.45      0.29       776\n'}, 'f1': {'test': 0.16590261293234257}}}

# %%
# 4 label ts cxr txt -- bi-level 0.05
print(load_data("/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_mi/los-48-cxr-notes-ecg/TS_CXR_Text/TS_48/Atten/f1/result.pkl"))
# Out:
# {'42': {'confusion_matrix': {'test': array([[ 91, 130,  11,   5],
#        [ 83, 210,  38,  17],
#        [ 18,  63,  36,  15],
#        [  4,  23,  21,  11]])}, 'classification_report': {'test': '                 precision    recall  f1-score   support\n\n       ≤ 3 days       0.46      0.38      0.42       237\n > 3 & ≤ 7 days       0.49      0.60      0.54       348\n> 7 & ≤ 14 days       0.34      0.27      0.30       132\n      > 14 days       0.23      0.19      0.21        59\n\n       accuracy                           0.45       776\n      macro avg       0.38      0.36      0.37       776\n   weighted avg       0.44      0.45      0.44       776\n'}, 'f1': {'test': 0.367771867397177}}}

# %% [markdown]
# # KL + MI

# %%
# 4 label 4 mods -- bi-level 0.05
print(load_data("/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_mi/los-48-cxr-notes-ecg-missingInd/TS_CXR_Text_ECG/TS_48/Atten/f1/result.pkl"))
# Out:
# {'42': {'confusion_matrix': {'test': array([[989, 637,  31,  72],
#        [766, 997, 181, 357],
#        [ 90, 285, 121, 349],
#        [ 20,  98,  72, 199]]), 'best_val': None}, 'classification_report': {'test': '                 precision    recall  f1-score   support\n\n       ≤ 3 days       0.53      0.57      0.55      1729\n > 3 & ≤ 7 days       0.49      0.43      0.46      2301\n> 7 & ≤ 14 days       0.30      0.14      0.19       845\n      > 14 days       0.20      0.51      0.29       389\n\n       accuracy                           0.44      5264\n      macro avg       0.38      0.42      0.37      5264\n   weighted avg       0.45      0.44      0.44      5264\n', 'best_val': None}, 'f1': {'test': 0.3742778046360571, 'best_val': None}}}

# %%
# 4 label ts ecg txt -- bi-level 0.05
print(load_data("/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_mi/los-48-cxr-notes-ecg-missingInd/TS_ECG_Text/TS_48/Atten/f1/result.pkl"))
# Out:
# {'42': {'confusion_matrix': {'test': array([[ 941,  709,   73,    6],
#        [ 771, 1100,  395,   35],
#        [ 106,  328,  381,   30],
#        [  34,  117,  217,   21]]), 'best_val': None}, 'classification_report': {'test': '                 precision    recall  f1-score   support\n\n       ≤ 3 days       0.51      0.54      0.53      1729\n > 3 & ≤ 7 days       0.49      0.48      0.48      2301\n> 7 & ≤ 14 days       0.36      0.45      0.40       845\n      > 14 days       0.23      0.05      0.09       389\n\n       accuracy                           0.46      5264\n      macro avg       0.40      0.38      0.37      5264\n   weighted avg       0.45      0.46      0.45      5264\n', 'best_val': None}, 'f1': {'test': 0.3736498630590587, 'best_val': None}}}

# %%
# 4 label ts cxr ecg -- bi-level 0.05
print(load_data("/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_mi/los-48-cxr-notes-ecg-missingInd/TS_CXR_ECG/TS_48/Atten/f1/result.pkl"))
# Out:
# {'42': {'confusion_matrix': {'test': array([[ 250, 1440,   39,    0],
#        [ 172, 1988,  140,    1],
#        [  20,  690,  134,    1],
#        [   6,  292,   88,    3]])}, 'classification_report': {'test': '                 precision    recall  f1-score   support\n\n       ≤ 3 days       0.56      0.14      0.23      1729\n > 3 & ≤ 7 days       0.45      0.86      0.59      2301\n> 7 & ≤ 14 days       0.33      0.16      0.22       845\n      > 14 days       0.60      0.01      0.02       389\n\n       accuracy                           0.45      5264\n      macro avg       0.49      0.29      0.26      5264\n   weighted avg       0.48      0.45      0.37      5264\n'}, 'f1': {'test': 0.2631126780207184}}}

# %%
# 4 label ts cxr txt -- bi-level 0.05
print(load_data("/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_mi/los-48-cxr-notes-ecg-missingInd/TS_CXR_Text/TS_48/Atten/f1/result.pkl"))
# Out:
# {'42': {'confusion_matrix': {'test': array([[ 458, 1206,   55,   10],
#        [ 337, 1677,  249,   38],
#        [  35,  530,  252,   28],
#        [   6,  212,  144,   27]]), 'best_val': None}, 'classification_report': {'test': '                 precision    recall  f1-score   support\n\n       ≤ 3 days       0.55      0.26      0.36      1729\n > 3 & ≤ 7 days       0.46      0.73      0.57      2301\n> 7 & ≤ 14 days       0.36      0.30      0.33       845\n      > 14 days       0.26      0.07      0.11       389\n\n       accuracy                           0.46      5264\n      macro avg       0.41      0.34      0.34      5264\n   weighted avg       0.46      0.46      0.43      5264\n', 'best_val': None}, 'f1': {'test': 0.3397662811963146, 'best_val': None}}}

# %% [markdown]
# # KL + CC (Subset)

# %%
# 4 label 4 mods -- bi-level 0.05
print(load_data("/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_cc/los-48-cxr-notes-ecg/TS_CXR_Text_ECG/TS_48/Atten/f1/result.pkl"))
# Out:
# {'42': {'confusion_matrix': {'test': array([[ 83, 129,  16,   9],
#        [ 68, 187,  67,  26],
#        [ 10,  38,  51,  33],
#        [  1,  16,  17,  25]])}, 'classification_report': {'test': '                 precision    recall  f1-score   support\n\n       ≤ 3 days       0.51      0.35      0.42       237\n > 3 & ≤ 7 days       0.51      0.54      0.52       348\n> 7 & ≤ 14 days       0.34      0.39      0.36       132\n      > 14 days       0.27      0.42      0.33        59\n\n       accuracy                           0.45       776\n      macro avg       0.41      0.42      0.41       776\n   weighted avg       0.46      0.45      0.45       776\n'}, 'f1': {'test': 0.4065757154606844}}}

# %%
# 4 label ts cxr txt -- bi-level 0.05
print(load_data("/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_cc/los-48-cxr-notes-ecg/TS_CXR_Text/TS_48/Atten/f1/result.pkl"))
# Out:
# {'42': {'confusion_matrix': {'test': array([[103, 117,  16,   1],
#        [ 91, 196,  53,   8],
#        [ 11,  59,  54,   8],
#        [  1,  31,  23,   4]])}, 'classification_report': {'test': '                 precision    recall  f1-score   support\n\n       ≤ 3 days       0.50      0.43      0.47       237\n > 3 & ≤ 7 days       0.49      0.56      0.52       348\n> 7 & ≤ 14 days       0.37      0.41      0.39       132\n      > 14 days       0.19      0.07      0.10        59\n\n       accuracy                           0.46       776\n      macro avg       0.39      0.37      0.37       776\n   weighted avg       0.45      0.46      0.45       776\n'}, 'f1': {'test': 0.36886780026012705}}}

# %% [markdown]
# # KL + CC

# %%
# 4 label 4 mods -- bi-level 0.05
print(load_data("/data/wang/junh/results/Fuse_moe/all_los/multiclass/dynamic_bilevel/los-48-cxr-notes-ecg-missingInd/TS_CXR_Text_ECG/TS_48/Atten/f1_0.5_0.05/result.pkl"))
# Out:
# {'42': {'confusion_matrix': {'test': array([[ 941,  740,   20,   28],
#        [ 718, 1288,  107,  188],
#        [  95,  449,  108,  193],
#        [  23,  177,   50,  139]])}, 'classification_report': {'test': '                 precision    recall  f1-score   support\n\n       ≤ 3 days       0.53      0.54      0.54      1729\n > 3 & ≤ 7 days       0.49      0.56      0.52      2301\n> 7 & ≤ 14 days       0.38      0.13      0.19       845\n      > 14 days       0.25      0.36      0.30       389\n\n       accuracy                           0.47      5264\n      macro avg       0.41      0.40      0.39      5264\n   weighted avg       0.47      0.47      0.46      5264\n'}, 'f1': {'test': 0.38612874720487295}}}

# %%
# 4 label ts ecg txt -- bi-level 0.05
print(load_data("/data/wang/junh/results/Fuse_moe/all_los/multiclass/dynamic_bilevel/los-48-cxr-notes-ecg-missingInd/TS_ECG_Text/TS_48/Atten/f1_0.5_0.1/result.pkl"))
# Out:
# {'42': {'confusion_matrix': {'test': array([[ 512, 1173,   42,    2],
#        [ 380, 1715,  205,    1],
#        [  48,  595,  200,    2],
#        [  14,  259,  113,    3]])}, 'classification_report': {'test': '                 precision    recall  f1-score   support\n\n       ≤ 3 days       0.54      0.30      0.38      1729\n > 3 & ≤ 7 days       0.46      0.75      0.57      2301\n> 7 & ≤ 14 days       0.36      0.24      0.28       845\n      > 14 days       0.38      0.01      0.02       389\n\n       accuracy                           0.46      5264\n      macro avg       0.43      0.32      0.31      5264\n   weighted avg       0.46      0.46      0.42      5264\n'}, 'f1': {'test': 0.3122680130135614}}}

# %%
# 4 label ts cxr ecg -- bi-level 0.05
print(load_data("/data/wang/junh/results/Fuse_moe/all_los/multiclass/dynamic_bilevel/los-48-cxr-notes-ecg-missingInd/TS_CXR_ECG/TS_48/Atten/f1_0.5_0.1/result.pkl"))
# Out:
# {'42': {'confusion_matrix': {'test': array([[1442,  273,   14,    0],
#        [1480,  758,   63,    0],
#        [ 307,  461,   77,    0],
#        [  73,  268,   47,    1]])}, 'classification_report': {'test': '                 precision    recall  f1-score   support\n\n       ≤ 3 days       0.44      0.83      0.57      1729\n > 3 & ≤ 7 days       0.43      0.33      0.37      2301\n> 7 & ≤ 14 days       0.38      0.09      0.15       845\n      > 14 days       1.00      0.00      0.01       389\n\n       accuracy                           0.43      5264\n      macro avg       0.56      0.31      0.27      5264\n   weighted avg       0.47      0.43      0.38      5264\n'}, 'f1': {'test': 0.27472717034632166}}}

# %%
# 4 label ts cxr txt -- bi-level 0.05
print(load_data("/data/wang/junh/results/Fuse_moe/all_los/multiclass/dynamic_bilevel/los-48-cxr-notes-ecg-missingInd/TS_CXR_Text/TS_48/Atten/f1_0.5_0.05/result.pkl"))
# Out:
# {'42': {'confusion_matrix': {'test': array([[1047,  620,   49,   13],
#        [ 867, 1123,  241,   70],
#        [ 114,  416,  223,   92],
#        [  29,  157,  139,   64]])}, 'classification_report': {'test': '                 precision    recall  f1-score   support\n\n       ≤ 3 days       0.51      0.61      0.55      1729\n > 3 & ≤ 7 days       0.48      0.49      0.49      2301\n> 7 & ≤ 14 days       0.34      0.26      0.30       845\n      > 14 days       0.27      0.16      0.20       389\n\n       accuracy                           0.47      5264\n      macro avg       0.40      0.38      0.39      5264\n   weighted avg       0.45      0.47      0.46      5264\n'}, 'f1': {'test': 0.3853260629577966}}}

# %% [markdown]
# # MI Only

# %%
# 4 label 4 mods
print(load_data("/data/wang/junh/results/Fuse_moe/all_los/multiclass/dynamic_mi/los-48-cxr-notes-ecg-missingInd/TS_CXR_Text_ECG/TS_48/Atten/f1/result.pkl"))
# Out:
# {'42': {'confusion_matrix': {'test': array([[ 916,  757,   45,   11],
#        [ 698, 1363,  185,   55],
#        [  88,  551,  161,   45],
#        [  21,  241,   90,   37]])}, 'classification_report': {'test': '                 precision    recall  f1-score   support\n\n       ≤ 3 days       0.53      0.53      0.53      1729\n > 3 & ≤ 7 days       0.47      0.59      0.52      2301\n> 7 & ≤ 14 days       0.33      0.19      0.24       845\n      > 14 days       0.25      0.10      0.14       389\n\n       accuracy                           0.47      5264\n      macro avg       0.40      0.35      0.36      5264\n   weighted avg       0.45      0.47      0.45      5264\n'}, 'f1': {'test': 0.3585671250122244}}}

# %%
# tc cxr txt
print(load_data('/data/wang/junh/results/Fuse_moe/all_los/multiclass/dynamic_mi/los-48-cxr-notes-ecg-missingInd/TS_CXR_Text/TS_48/Atten/f1/result.pkl'))
# Out:
# {'42': {'confusion_matrix': {'test': array([[1399,  253,   52,   25],
#        [1321,  572,  259,  149],
#        [ 241,  232,  228,  144],
#        [  59,  108,  122,  100]])}, 'classification_report': {'test': '                 precision    recall  f1-score   support\n\n       ≤ 3 days       0.46      0.81      0.59      1729\n > 3 & ≤ 7 days       0.49      0.25      0.33      2301\n> 7 & ≤ 14 days       0.34      0.27      0.30       845\n      > 14 days       0.24      0.26      0.25       389\n\n       accuracy                           0.44      5264\n      macro avg       0.38      0.40      0.37      5264\n   weighted avg       0.44      0.44      0.40      5264\n'}, 'f1': {'test': 0.367465115434028}}}

# %% [markdown]
# # KL Only

# %%
# 4 label 4 mods
print(load_data("/data/wang/junh/results/Fuse_moe/all_los/multiclass/dynamic_weighted/los-48-cxr-notes-ecg/TS_CXR_Text_ECG/TS_48/Atten/f1_0.5_0.1/result.pkl"))
# Out:
# {'42': {'confusion_matrix': {'test': array([[135,  76,   9,  17],
#        [141, 138,  31,  38],
#        [ 21,  51,  25,  35],
#        [  4,  20,  10,  25]])}, 'classification_report': {'test': '                 precision    recall  f1-score   support\n\n       ≤ 3 days       0.45      0.57      0.50       237\n > 3 & ≤ 7 days       0.48      0.40      0.44       348\n> 7 & ≤ 14 days       0.33      0.19      0.24       132\n      > 14 days       0.22      0.42      0.29        59\n\n       accuracy                           0.42       776\n      macro avg       0.37      0.39      0.37       776\n   weighted avg       0.43      0.42      0.41       776\n'}, 'f1': {'test': 0.3666949772410846}}}

# %%
# 4 label TS_CXR_ECG -- with smooth init=0.5 decay=0.1
print(load_data("/data/wang/junh/results/Fuse_moe/all_los/multiclass/dynamic_weighted/los-48-cxr-notes-ecg/TS_CXR_ECG/TS_48/Atten/f1/result.pkl"))
# Out:
# {'42': {'confusion_matrix': {'test': array([[154,  68,  15,   0],
#        [163, 119,  60,   6],
#        [ 37,  36,  49,  10],
#        [ 10,  21,  25,   3]])}, 'classification_report': {'test': '                 precision    recall  f1-score   support\n\n       ≤ 3 days       0.42      0.65      0.51       237\n > 3 & ≤ 7 days       0.49      0.34      0.40       348\n> 7 & ≤ 14 days       0.33      0.37      0.35       132\n      > 14 days       0.16      0.05      0.08        59\n\n       accuracy                           0.42       776\n      macro avg       0.35      0.35      0.34       776\n   weighted avg       0.42      0.42      0.40       776\n'}, 'f1': {'test': 0.3350459384199488}}}

# %%
## 4 label TS_ECG_Text -- with smooth init=0.5 decay=0.05
print(load_data("/data/wang/junh/results/Fuse_moe/all_los/multiclass/dynamic_weighted/los-48-cxr-notes-ecg/TS_ECG_Text/TS_48/Atten/f1_0.5_0.05/result.pkl"))
# Out:
# {'42': {'confusion_matrix': {'test': array([[ 84, 131,  16,   6],
#        [ 75, 191,  58,  24],
#        [ 13,  44,  49,  26],
#        [  1,  18,  23,  17]])}, 'classification_report': {'test': '                 precision    recall  f1-score   support\n\n       ≤ 3 days       0.49      0.35      0.41       237\n > 3 & ≤ 7 days       0.50      0.55      0.52       348\n> 7 & ≤ 14 days       0.34      0.37      0.35       132\n      > 14 days       0.23      0.29      0.26        59\n\n       accuracy                           0.44       776\n      macro avg       0.39      0.39      0.39       776\n   weighted avg       0.45      0.44      0.44       776\n'}, 'f1': {'test': 0.3854269410613779}}}

# %%
## 4 label TS_CXR_Text -- with smooth init=0.5 decay=0.05
print(load_data("/data/wang/junh/results/Fuse_moe/all_los/multiclass/dynamic_weighted/los-48-cxr-notes-ecg/TS_CXR_Text/TS_48/Atten/f1_0.5_0.05/result.pkl"))
# Out:
# {'42': {'confusion_matrix': {'test': array([[ 79, 134,  22,   2],
#        [ 63, 185,  87,  13],
#        [  9,  38,  79,   6],
#        [  0,  16,  36,   7]])}, 'classification_report': {'test': '                 precision    recall  f1-score   support\n\n       ≤ 3 days       0.52      0.33      0.41       237\n > 3 & ≤ 7 days       0.50      0.53      0.51       348\n> 7 & ≤ 14 days       0.35      0.60      0.44       132\n      > 14 days       0.25      0.12      0.16        59\n\n       accuracy                           0.45       776\n      macro avg       0.41      0.40      0.38       776\n   weighted avg       0.46      0.45      0.44       776\n'}, 'f1': {'test': 0.38128310100961316}}}
