# %%
import numpy as np
import pickle
import copy
import torch
from torch.nn import functional as F
import os
import skimage.io
import torchvision.transforms as T
import cv2
import torchxrayvision as xrv
from tqdm import tqdm
from PIL import Image
from kornia.augmentation import RandomCrop

# %%
def rename_original_file(file_path):
    """ Rename the original file to include '_original' in its filename. """
    new_file_path = file_path.replace('.pkl', '_original.pkl')
    os.rename(file_path, new_file_path)
    return new_file_path

# %%
import openai
from openai import OpenAI
# Set your OpenAI API key here
api_key = '.'

# %%
client = OpenAI(api_key = api_key)

# %%
def augment_time_series(data):
    """ Augment time series data by adding Gaussian noise directly to a numpy array. """
    mean = 0
    std = 0.1
    if data is not None:
        noise = np.random.normal(mean, std, data.shape)
        return data + noise
    return data

# %%
def augment_text(original_text):
    """ Use GPT-3.5-turbo to rewrite a chest X-ray report. """
    prompt=f'''
    Rewrite the following chest X-ray report using different wording while maintaining all medical facts and implications. 
    Please ensure the generated text remains in the same format as the input. 
    Only return the rewritten report without any additional commentary: {original_text}'''

    my_message = [
        {'role': 'system', 'content': 'You are a radiologist rewriting a chest X-ray report.'},
        {'role': 'user', 'content': prompt}
    ]

    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=my_message,
        max_tokens=1024,
        temperature=0,
    )
    return response.choices[0].message.content

# %%
from transformers import AutoTokenizer, AutoModel, logging
logging.set_verbosity_error()
# biobert_path = '../pretrained_models/bio_clinical_bert/biobert_pretrain_output_all_notes_150000/'
# biobert_path = '/cis/home/charr165/vscode_projects/HAIM/pretrained_bert_tf/bert_pretrain_output_all_notes_150000'
# biobert_tokenizer = AutoTokenizer.from_pretrained(biobert_path)
# biobert_model = AutoModel.from_pretrained(biobert_path)
biobert_tokenizer = AutoTokenizer.from_pretrained("emilyalsentzer/Bio_ClinicalBERT")
biobert_model = AutoModel.from_pretrained("emilyalsentzer/Bio_ClinicalBERT")
longformer_tokenizer = AutoTokenizer.from_pretrained("yikuan8/Clinical-Longformer")
longformer_model = AutoModel.from_pretrained("yikuan8/Clinical-Longformer")

# %%
def get_biobert_embeddings(text, device, modelname='longformer'):

    # Move the BioBERT model to the specified device
    biobert_model.to(device)
    longformer_model.to(device)

    if modelname == 'biobert':
        # Tokenize text and move tokens to the same device
        tokens_pt = biobert_tokenizer(text, return_tensors="pt", padding="max_length", max_length=512,truncation=True).to(device)

        # Get outputs from BioBERT model
        outputs = biobert_model(**tokens_pt)
    elif modelname == 'longformer':
        # Tokenize text and move tokens to the same device
        tokens_pt = longformer_tokenizer(text, return_tensors="pt", max_length=1024, padding="max_length", truncation=True).to(device)

        # Get outputs from BioBERT model
        outputs = longformer_model(**tokens_pt)

    # Extract last hidden state and pooler output (both on the GPU)
    last_hidden_state = outputs.last_hidden_state
    pooler_output = outputs.pooler_output

    # No conversion to numpy, stay as tensors
    hidden_embeddings = last_hidden_state
    embeddings = pooler_output

    return embeddings, hidden_embeddings

# %%
def process_batch(chunk_batch, device):
    """ Process a batch of text chunks to generate embeddings. """
    embeddings_batch = []
    for chunk in chunk_batch:
        curr_embeddings, _ = get_biobert_embeddings(chunk, device)  # Assuming this function is defined elsewhere
        embeddings_batch.append(curr_embeddings.detach().cpu().numpy())
    return embeddings_batch

# %%
def augment_image(image_path, image_size=(2539, 3050), shift=100):
    """ Augment image by applying a random crop. """
    image = Image.open(image_path)
    image = np.array(image) / 255
    image = torch.tensor(image).unsqueeze(0)
    transform = RandomCrop(size=image_size)
    image = transform(image) * 255
    image = image.squeeze().numpy().astype(np.uint8)
    augmented_image_path = image_path.replace('.jpg', '_augmented.jpg')
    Image.fromarray(image).save(augmented_image_path)
    return augmented_image_path

# %%
def generate_cxr_feats(image_paths, model):
    """ Generate CXR features for a list of image paths using a pre-trained Densenet model. """
    img_list = []
    for image_path in image_paths:
        img = skimage.io.imread(image_path)
        img = xrv.datasets.normalize(img, 255)
        img = cv2.resize(img, (224, 224), interpolation=cv2.INTER_AREA)
        img = np.expand_dims(img, axis=0)  # Add channel dimension
        img_list.append(img)

    # Convert the list of image arrays into a batch tensor
    img_batch = np.stack(img_list, axis=0)  # This should be (n_images, 1, 224, 224)
    img_batch = torch.from_numpy(img_batch).float().cuda()

    with torch.no_grad():
        feats = model.features(img_batch)
        feats = F.relu(feats, inplace=True)
        feats = F.adaptive_avg_pool2d(feats, (1, 1))
        densefeatures_batch = feats.cpu().detach().numpy().reshape(len(img_list), -1)

    return densefeatures_batch

# %%
def load_data(file_path):
    """ Load the data from a pickle file. """
    with open(file_path, 'rb') as f:
        return pickle.load(f)

def save_data(data, file_path):
    """ Save the data to a pickle file. """
    with open(file_path, 'wb') as f:
        pickle.dump(data, f)

# %%
def single_augmentation(patient_data, text_device, cxr_model):
    """ Augment a single instance of patient data. """
    # Copy the original data to keep it unchanged
    aug_patient_data = copy.deepcopy(patient_data)
    
    # Augment the time series data
    if 'irg_ts' in aug_patient_data and aug_patient_data['irg_ts'] is not None:
        aug_patient_data['irg_ts'] = augment_time_series(aug_patient_data['irg_ts'])
    if 'reg_ts' in aug_patient_data and aug_patient_data['reg_ts'] is not None:
        aug_patient_data['reg_ts'] = augment_time_series(aug_patient_data['reg_ts'])
    
    # Augment and handle text data
    if not aug_patient_data['text_missing']:
        aug_texts = [augment_text(text) for text in aug_patient_data['text_data']]
        aug_patient_data['text_data'] = aug_texts
        # Generate text embeddings
        aug_patient_data['text_embeddings'] = [process_batch([text], text_device) for text in aug_texts]

    # Augment and handle image data
    if not aug_patient_data['cxr_missing']:
        aug_image_paths = [augment_image(path) for path in aug_patient_data['image_paths']]
        aug_patient_data['image_paths'] = aug_image_paths
        # Generate CXR features
        aug_patient_data['cxr_feats'] = generate_cxr_feats(aug_image_paths, cxr_model)

    # Ignore the ECG data by setting the missing flag
    aug_patient_data['ecg_missing'] = True
    
    return aug_patient_data

# %%
def count_classes(data):
    """ Count instances in each class. """
    counts = {}
    for item in data:
        label = item['label']
        if label in counts:
            counts[label] += 1
        else:
            counts[label] = 1
    return counts

def augment_data_conditionally(file_path, text_device, cxr_model):
    data = load_data(file_path)
    counts = count_classes(data)
    num_majority = max(counts.values())
    num_minority = counts.get(1, 0)  # Assuming label '1' is the minority class

    if num_minority == 0:
        raise ValueError("No instances of the minority class found.")

    num_augmentations = math.ceil((num_majority - num_minority) / num_minority)
    augmented_data = []

    for item in data:
        augmented_data.append(item)
        if item['label'] == 1:
            for _ in range(num_augmentations):
                augmented_instance = single_augmentation(copy.deepcopy(item), text_device, cxr_model)
                augmented_data.append(augmented_instance)

    # Save the augmented data
    save_data(augmented_data, file_path)

# %%
file_path = '/data/wang/junh/datasets/multimodal/augmentation/pid_3mod/train_los_S_stays.pkl'
augment_data(file_path, text_device='cuda:3', cxr_model=xrv.models.DenseNet(weights="all").cuda())
# Out:
# 100%|██████████| 115/115 [14:40<00:00,  7.66s/it]

# %%
file_path = '/data/wang/junh/datasets/multimodal/augmentation/pid_3mod/train_ihm_S_stays.pkl'
augment_data(file_path, text_device='cuda:3', cxr_model=xrv.models.DenseNet(weights="all").cuda())
# Out:
#  67%|██████▋   | 120/178 [23:11<15:03, 15.58s/it]

# %%
# Example usage
original_cxr_report = train_stays_list[0].get('text_data')[1]
metadata = train_stays_list[0].get('cxr_metadata')[1]

# %%
original_cxr_report
# Out:
# 'INDICATION:  ___ year old man with new ventricular tachycardia status post\nablation also volume overload\n\nTECHNIQUE:  Frontal chest radiographs were obtained with the patient in the\nsupine position.\n\nCOMPARISON:  Radiographs from ___.\n\nFINDINGS: \n\nThe heart continues to be enlarged, and a left cardiac device has its leads\nterminating in appropriate position. There is moderate edema with associated\nright layering profusion. An endotracheal tube terminates in appropriate\nposition, and the nasogastric tube terminates below the view of this\nradiograph.\n\nIMPRESSION: \n\nContinued moderate pulmonary edema with layering right pleural effusion.\n'

# %%
# Augment text
augmented_text = augment_text(original_cxr_report)
print("Augmented Text:", augmented_text)
# Out:
# Augmented Text: INDICATION:  Chest X-ray of a ___ year old man with recent ventricular tachycardia ablation and volume overload.
#
# TECHNIQUE:  Frontal chest radiographs were taken with the patient lying supine.
#
# COMPARISON:  Prior radiographs not available for comparison.
#
# FINDINGS:
#
# The heart remains enlarged, and a left cardiac device is appropriately positioned with its leads. Moderate edema is present with right pleural effusion. The endotracheal tube and nasogastric tube are both appropriately positioned.
#
# IMPRESSION:
#
# Persistent moderate pulmonary edema with right pleural effusion.

# %%
for stays in train_stays_list:
    print(stays['text_data'][0])
# Out:
# A chest fluoro was performed without a radiologist present.  2 minutes and 59
# seconds of fluoro time was used.  Films were submitted to PACS.
#
#
# INDICATION:  ___ male with lactic acidosis, severe mitral
# regurgitation, and tachypnea.
#
# COMPARISON:  ___.
#
# TECHNIQUE:  Single frontal chest radiograph was obtained portably with the
# patient in an upright position.
#
# FINDINGS:  Compared to prior exam, there has been no significant interval
# change.  Moderate cardiomegaly and pulmonary vascular congestion persist.  No
# focal consolidation is detected on this single view.  There may be trace right
# pleural effusion.  No pneumothorax is detected.
#
# IMPRESSION:  Stable chest radiograph.
#
# HISTORY:  CHF.
#
# FINDINGS:  In comparison with study of ___, there is diffuse bilateral
# pulmonary opacifications in a pattern consistent with the clinical diagnosis
# of congestive failure.  Cardiac silhouette is more prominent, though some of
# this may be due to the portable supine position.  The left hemidiaphragm is
# poorly seen, suggesting some layering pleural effusion on this side.  In the
# appropriate clinical setting, it would be difficult to exclude supervening
# pneumonia.
#
# The endotracheal tube tip lies approximately 5.3 cm above the carina.
# Nasogastric tube extends well into the stomach.
#
# REASON FOR EXAMINATION:  Evaluation of the patient after mitral valve
# replacement.
#
# No prior studies available for comparison.
#
# Cardiomegaly is substantial, diffuse.  Mitral valve is replaced.
# Post-sternotomy wires are unremarkable.
#
# There is most likely present bilateral pleural effusion. Perihilar vascular
# engorgement is noted as well as bilateral mid lung opacities.  They might
# reflect the presence of pulmonary edema, but infectious process or aspiration
# is another possibility.  There is no pneumothorax.
#
# ADDENDUM  To clarify, the left and right main pulmonary arteries were
# catheterized in addition to the right upper, middle and lower segmental
# pulmonary artery branches were all catheterized for angiography and suction
# thrombectomy.
#
# INDICATION:  ___ year old man with unresponsiveness; suspected toxidrome  //
# Please evaluate for acute intrathoracic process, widened mediastinum?
#
# TECHNIQUE:  Single portable semi upright view of the chest
#
# COMPARISON:  ___
#
# FINDINGS:
#
# Lung volumes remain extremely low.  Previously seen atelectasis and pleural
# effusion at the left base has improved.  Mild pulmonary edema persists.  There
# is no focal consolidation, pulmonary edema, or pneumothorax.
#
# IMPRESSION:
#
# The left lower lung is better aerated and the left effusion has decreased
# however lung volumes remain very low.  Mild pulmonary edema persist.
#
# EXAMINATION:  CT HEAD W/O CONTRAST Q111 CT HEAD
#
# INDICATION:  ___ year old man with history of distant Subdural and craniectomy
# now which progressive ams/somnolence and epileptiform discharges.  // Evidence
# of change in suspicious area under previous craniotomy (post op changes vs
# Subdural)
#
# TECHNIQUE:  Axial images were acquired through the paranasal sinuses.  Bone
# and soft tissue reconstructed images were generated. Coronal reformatted
# images were then produced.
#
# DOSE:   This study involved 3 CT acquisition phases with dose indices as
# follows:
#    1) CT Localizer Radiograph
#    2) CT Localizer Radiograph
#    3) Sequenced Acquisition 4.8 s, 16.2 cm; CTDIvol = 52.3 mGy (Head) DLP =
# 848.0 mGy-cm.
#  Total DLP (Head) = 848 mGy-cm.
#
# COMPARISON:  CTA without contrast of ___.
#
# FINDINGS:
#
# The patient is status post remote right frontal parietal and temporal
# craniotomy.  Surface electrodes for EEG are noted, slightly limiting
# evaluation of the adjacent structures secondary to artifact.  Within these
# confines:
#
# Re- identified is a thin 2-3 mm thick crescentic dural hyperdensity underlying
# the craniotomy (series 3, image 17), unchanged in configuration in
# distribution from examination of approximately 11 hr prior.  The stability of
# the finding would suggest that this may be postoperative change rather than
# subdural hematoma.
#
# There is no evidence of acute infarct.  There are periventricular and
# subcortical white matter hypodensities, which are nonspecific, but may be seen
# in setting of chronic microangiopathy in a patient of this age.  Sulci,
# ventricles and cisterns are within expected limits given the degree of age
# related global cerebral volume loss.  The paranasal sinuses are essentially
# clear.  The orbits are unremarkable.  The mastoid air cells are clear.
#
# IMPRESSION:
#
#
# 1. Unchanged appearance of 2-3 mm thick crescentic hyperdensity overlying the
# right frontal lobe, underlying a right frontal parietal temporal craniotomy.
# Given its stability over approximately 11 hr, this likely represents chronic
# postoperative dural thickening rather than subdural hematoma.  Close attention
# on followup is recommended.
# 2. White matter changes compatible with chronic microangiopathy in a patient
# of this age.  Otherwise, there is no evidence of acute territorial infarct or
# other foci suspicious for hemorrhage.
#
# RECOMMENDATION(S):  As there are no additional findings to suggest etiology of
# patient's symptoms, MRI may be more sensitive for subtle infarcts or other
# lesions.
#
# HISTORY:  Liver transplant.
#
# FINDINGS:  In comparison with study of ___, there has been placement of an
# endotracheal tube with the tip approximately 3.5 cm above the carina.  The
# left Swan-Ganz catheter tip is in the proximal pulmonary artery.  Hemodialysis
# catheter tip remains in the right atrium.  Left IJ catheter is in the region
# of the juncture with the left subclavian vein.  Abdominal drains are seen
# bilaterally.
#
# Nasogastric tube extends only to the lower thoracic esophagus.  It could be
# advanced 20-25 cm, which was conveyed to Dr. ___ by the resident on-call.
#
# Mild indistinctness of pulmonary vessels suggests some elevated pulmonary
# venous pressure.
#
# SINGLE FRONTAL VIEW OF THE CHEST
#
# REASON FOR EXAM:  Afib, patient with aortic stenosis and hypertension.
#
# Mild-to-moderate cardiomegaly is accentuated by the projection and low lung
# volumes.  The aorta is tortuous and dilated.  There is no pneumothorax or
# pleural effusion.  There is elevation of the left hemidiaphragm.  Mild
# pulmonary edema has improved.  There are no new lung abnormalities.
#
# INDICATION:  ___ year old woman with new tracheostomy, OGT  // OGT placement,
# acute interval change
#
# TECHNIQUE:  Portable chest radiograph.
#
# COMPARISON:  Chest radiograph dated ___.
#
# FINDINGS:
#
# The tracheostomy tube is in place at satisfactory position.  The OG tube is
# not visualized on the radiograph.
#
# The lung volume is significantly decreased, partially due to patient position.
# There is obscuring of the left hemidiaphragm, consistent with left lower lobe
# collapse.  No consolidation.  No pleural effusion.  No pneumothorax.  The
# cardiac silhouette is slightly enlarged compared to prior, partially due to
# patient position.  The mediastinum is normal.  The stomach is significantly
# dilated.  No fractures.
#
# IMPRESSION:
#
# 1.  OG tube is not visualized on the chest radiograph.  Tracheostomy tube is
# in satisfactory position without complication.
#
# 2.  Left lower lobe collapse.
#
# NOTIFICATION:   The findings were discussed with the ICU team by ___,
# M.D. on the telephone on ___ at 10:40AM, 5 minutes after discovery of the
# findings.
#
# STUDY:  AP chest ___.
#
# CLINICAL HISTORY:  ___ man with hypoxia and tachypnea.  Evaluate for
# increased pulmonary edema.
#
# FINDINGS:  Comparison is made to prior study from ___.
#
# There is again seen mild pulmonary edema.  There are bilateral pleural
# effusions which have increased.  There is a persistent left retrocardiac
# opacity and unchanged cardiomegaly.  There are no pneumothoraces.
#
# PORTABLE CHEST X-RAY OF ___
#
# COMPARISON:  Chest radiograph of one day earlier.
#
# FINDINGS:  Continued improved aeration of the left lung with residual left
# basilar atelectasis and adjacent pleural effusion.  However, worsening
# pulmonary vascular congestion and interstitial edema as well as increasing
# small right pleural effusion as compared to the prior study.
#
# INDICATION:  ___ year old woman with cirrhosis now with GI bleed  // line
# placement / ___ more placement
#
# TECHNIQUE:  Portable supine abdominal radiograph was obtained.
#
# COMPARISON:  Portable abdominal radiograph ___
#
# FINDINGS:
#
# A ___ device is in the stomach with tip possibly in the post pyloric
# position.  There is diffuse gaseous distention of small bowel loops measuring
# up to 3.5 cm.  There is a paucity of gas within the colon.
# Supine assessment limits detection for free air; there is no gross
# pneumoperitoneum.
# Osseous structures are unremarkable.
# There are no unexplained soft tissue calcifications or radiopaque foreign
# bodies.
#
# IMPRESSION:
#
# 1.  ___ device is appropriately positioned with balloon inflated in the
# stomach on the second image.
# 2.  Mildly dilated loops of small bowel are consistent with ileus.
#
# HISTORY:  Status post total chest compression.
#
# ___.
#
# FINDINGS:
#
# Compared to the prior study there is no significant interval change.  There is
# no mediastinal widening, pneumothorax, fracture or new infiltrate.
#
# IMPRESSION:
#
# No fracture identified.
#
#
# EXAMINATION:  CHEST (PORTABLE AP)
#
# INDICATION:  ___ year old woman with COPD, Dementia, presents from nursing home
# with cough, found to be tachycardic and hypotensive  // evaluate for
# consolidation vs pneumonia     evaluate for consolidation vs pneumonia
#
# IMPRESSION:
#
# In comparison with the study of earlier in this date, there is little change.
# Extensive fibrotic process is again noted as well as dense calcification in
# the region of the mitral annulus.  Continued enlargement of the cardiac
# silhouette with indistinctness of pulmonary vessels that could reflect some
# elevation of pulmonary venous pressure.
# Pulmonary changes, it would be very difficult to exclude superimposed
# pneumonia in the appropriate clinical setting.
#
# EXAMINATION:  CHEST (PORTABLE AP)
#
# INDICATION:  ___ year old man with chronic trach, here with tachypnea  //
# Please eval for interval change
#
# COMPARISON:  ___.
#
# IMPRESSION:
#
# As compared to the previous examination, no relevant change is seen.  Mild
# bilateral basal areas of opacities.  Old left-sided rib fractures. Moderate
# cardiomegaly persists.  No relevant change in position of the tracheostomy
# tube.
#
# EXAMINATION:  CHEST (PORTABLE AP)
#
# INDICATION:  ___ year old woman with massive pe.  // Interval change
# Interval change
#
# IMPRESSION:
#
# Heart size and mediastinum are unchanged in appearance.  There is increase in
# left hilar opacity, although it might be just a better projection compared to
# previous chest radiograph.  No new consolidations demonstrated.  No pleural
# effusion seen.  No pneumothorax seen.
#
# PORTABLE AP CHEST X-RAY
#
# INDICATION:  Patient with left foot amputation, shortness of breath.
#
# COMPARISON:  ___.
#
# FINDINGS:
#
# Mild-to-moderate pulmonary edema has worsened since this morning.
# Cardiomegaly is severe in this patient with dual-lead pacemaker.  The distal
# end of the jugular line is hard to assess due to the superimposed pacemaker.
# Pleural effusions are small if any.  There is no pneumothorax.
#
# CONCLUSION:
#
# Worsening of mild-to-moderate pulmonary edema.
#
# INDICATION:  ___ year old man with left pleural effusion s/p left chest tube
# placement  // ptx   Contact name: ___: ___
#
# COMPARISON:  Chest radiographs ___ and chest CT, ___.
#
# FINDINGS:
#
# Small left pleural effusion has decreased since ___ following insertion of
# a left basal pigtail pleural drainage catheter.  There is no pneumothorax.
# Large left suprahilar mass has been evaluated.  Previous mild pulmonary edema
# has improved.  Right basal consolidation or atelectasis unchanged.  Heart
# partially obscured, mildly enlarged.
#
# IMPRESSION:
#
# Small left pleural effusion has decreased since ___ following insertion of
# a left basal pigtail pleural drainage catheter. There is no pneumothorax.
# Large left suprahilar mass has been evaluated.  Previous mild pulmonary edema
# has improved.  Right basal consolidation or atelectasis unchanged.  Heart
# partially obscured, mildly enlarged.
#
# EXAMINATION:  CHEST (PORTABLE AP)
#
# INDICATION:  ___ year old woman with lung cancer with mets to T12 spine, s/p VF
# cardiac arrest, inferior STEMI and IABP  // ?s/p PCI and IABP     ?s/p PCI and
# IABP
#
# IMPRESSION:
#
# In comparison with the study of ___, there is an endotracheal tube with its
# tip approximately 4 cm above the carina.  IABP tip lies approximately 1.2 cm
# below the transverse arch of the aorta.  The device could be pulled back about
# 1 cm to be in more optimal position.
# There is again increased opacification in the retrocardiac region with poor
# visualization of the hemidiaphragm, consistent with volume loss in the left
# lower lobe and small pleural effusion.
# Spinal fusion device is again seen in the thoracolumbar region.
#
# EXAMINATION:  CHEST (PORTABLE AP)
#
# INDICATION:  ___ year old man with new intubation  // ETT placement      ETT
# placement
#
# IMPRESSION:
#
# ET tube tip is 7.3 cm above the carinal.  Heart size and mediastinum are
# stable.  Bibasal areas of atelectasis have progressed since the prior study.
# Lucency in the right upper lung is related to severe emphysema.  Small
# bilateral pleural effusion.
#
# EXAMINATION:  CHEST (PORTABLE AP)
#
# INDICATION:  ___ year old man with SOB and tachypnea in the setting of recent
# ARDS.  // Interval change?
#
# TECHNIQUE:  Portable chest
#
# ___.
#
# FINDINGS:
#
# The NG tube tip is in the proximal stomach. Left-sided PICC line tip is at the
# cavoatrial junction.  Lung volumes are low with volume loss at the bases.
# There is hazy increased opacity in the retrocardiac region that could
# represent an infiltrate. This is slightly more prominent than on the prior
# studies. In addition the right hilum appears very prominent but this is felt
# to be projectional there is a small right lower lobe opacity that could be due
# to volume loss versus early infiltrate
#
# IMPRESSION:
#
# Slight worse appearance to the lower lungs. Is unclear if this is all due to
# volume loss surface there is an underlying infectious infiltrate.
#
# HISTORY:  AVR.
#
# FINDINGS:  In comparison with the pre-operative study of ___, there are now
# intact midline sternal wires.  Endotracheal tube tip lies approximately 5 cm
# above the carina.  Right Swan-Ganz catheter extends only to the right atrium.
# Nasogastric tube extends to the stomach, though the sidehole is probably above
# the esophagogastric junction.  There is no evidence of pneumothorax.
#
# Some atelectatic changes and possible small effusion at the left base.
#
# REASON FOR EXAMINATION:  Shortness of breath, wheezing, suspected pulmonary
# edema.
#
# AP radiograph of the chest was reviewed in comparison to ___.
#
# There is interval development of widespread parenchymal opacities, perihilar,
# concerning for pulmonary edema.  Underlying infectious process is a
# possibility and patient should be reassessed after diuresis.  Heart size and
# mediastinum are enlarged but unchanged since the prior study.
#
# INDICATION:  Status post PEA arrest.
#
# COMPARISONS:  Chest radiograph ___.  Chest radiograph ___.
#
# FINDINGS:  An endotracheal tube is approximately 8 cm from the carina and
# should be advanced.  A hemodialysis catheter is unchanged in position and ends
# in the mid SVC.  A left subclavian central line is coiled within the left
# brachiocephalic vein.  Since the prior radiograph, there has been interval
# development of severe pulmonary edema.  The cardiomediastinal silhouette is
# normal.  There are no pleural effusions.  There is no pneumothorax or visible
# rib fractures.
#
# IMPRESSION:
# 1.  Endotracheal tube approximately 8 cm from the carina and slightly high.
# 2.  Left subclavian central line coiled in the brachiocephalic vein.
# 3.  New moderate-to-severe pulmonary edema.
#
# EXAMINATION:  CHEST (PORTABLE AP)
#
# INDICATION:  ___ year old man with HIV and multifocal pneumonia with left lower
# lobe collapse on prior X-ray currently intubated.  // Please evaluate for
# interval change.     Could be either
#
# IMPRESSION:
#
# Compared to prior chest radiographs since ___, most recently ___.
#
# Moderate cardiomegaly has increased and mediastinal vascular engorgement
# suggests increased intravascular pressure or volume.  Extensive bilateral
# pulmonary consolidation has increased dramatically since ___.  Pneumonia
# is certainly a possibility, but concurrent pulmonary edema should be
# considered as well because of the year repeated the and concurrent increase in
# heart size.  Pleural effusions are presumed, but not large.
#
# ET tube is in standard placement.  Nasogastric tube passes below the diaphragm
# and out view.
#
# EXAMINATION:  CHEST (PORTABLE AP)
#
# INDICATION:  ___ year old woman with pancreatic cancer with liver abscesses,
# now with likely septic shock  // eval for pna, pulm edema
#
# TECHNIQUE:  Single frontal view of the chest
#
# COMPARISON:  ___
#
# FINDINGS:
#
# Cardiac size is normal.  There are low lung volumes.  Faint ill-defined
# opacities in the upper lobes and right mid lung are more conspicuous before.
# Left lower lobe minimal atelectasis are stable.  There is no pneumothorax or
# large pleural effusion.  Left central catheter tip is in the cavoatrial
# junction.  Lung nodules are better seen in concurrent abdomen CT
#
# IMPRESSION:
#
# Faint ill-defined opacities in the upper lobes, differential diagnosis is
# broad could represent infection, aspiration.  .  There is no evidence of
# pulmonary edema
#
# EXAMINATION:  CT CHEST W/O CONTRAST
#
# INDICATION:  ___ with a past medical history of CHF (EF 30%), ILD and COPD (on
# home ___, severe pHTN on tadalafil with dilated RV and severe TR, CKD
# (sCr: 1.5) who is transferred to ___ from OSH for dyspnea. Patient has had
# numerous admissions to ___, most recently for HCAP. Patient was discharged
# to ___ and Rehab.  // pls eval for focal pulmonary findings. +
# urine legionella Ag
#
# TECHNIQUE:  Axial multidetector CT images were obtained through the thorax
# without intravenous contrast.  Reformatted coronal, sagittal, thin slice axial
# images images were submitted to ___ and reviewed.
#
# DOSE:  Acquisition sequence:
#    1) Spiral Acquisition 4.4 s, 34.5 cm; CTDIvol = 11.4 mGy (Body) DLP = 394.3
# mGy-cm.
#  Total DLP (Body) = 394 mGy-cm.
#
# COMPARISON:  CT chest ___
#
# FINDINGS:
#
# Lungs:
#
# Parenchyma and Airways: Centrilobular emphysema in the upper lumps.
# Paraseptal emphysema upper lungs, with large subpleural blebs.  There is
# pulmonary fibrosis, with peripheral, subpleural distribution honeycombing more
# prominent in the lower lungs, suggesting UIP.  There is mild mucous plugging
# in the right lower lobe, new since prior.  There is increased volume of fluid
# within large cavitary area in the right lung apex compared with ___, is new since ___.  No definite soft tissue component or
# calcification.  .  Surrounding area of consolidation, nodularity has improved.
# Additional small opacities in the bilateral lower lobes are new, represent
# infection or aspiration.
# Vessels: Enlarged central pulmonary artery, consistent with pulmonary artery
# hypertension.  Aorta is of normal caliber.  There are coronary artery
# calcifications.
#
# Mediastinum and Hila: Stable partially calcified mediastinal lymph nodes.  .
#
# Heart and Pericardium: Heart is enlarged.  Coronary artery calcifications.
# Suggestion of anemia.
#
# Pleura: No pleural effusions.
#
# Neck, Thoracic Inlet, Axillae, Chest Wall: Left PICC line in place tip in the
# low SVC.  No mass.  No adenopathy.
#
# Upper Abdomen: Chololithiasis.  No pericholecystic inflammatory changes.
# There is benign simple left renal cysts, partially seen, stable.  Pancreas is
# atrophic.  Small esophageal hiatal hernia.
#
# Chest Cage: Degenerative changes spine.
#
# IMPRESSION:
#
# Increased fluid within right upper lung cavity, suggesting residual infection,
# with improved surrounding launch consolidation.  Few small nodules in the
# bilateral lower lobes, likely infectious, possibly aspiration.  Mild mucous
# plugging in the right lower lobe.
# Upper lung emphysema with lower lung fibrosis, UIP pattern.
# Pulmonary artery hypertension.
#
# INDICATION:  ___ female with intracranial hemorrhage and altered
# mental status.
#
# COMPARISON:  ___ at approximately 3 p.m.
#
# TECHNIQUE:  Axial CT images through the head were acquired without intravenous
# contrast.  Images through the top half of the head were repeated due to motion
# artifact, with improvement.  Coronal and sagittal reformatted images were
# reviewed.
#
# FINDINGS:  Tiny focus of hyperdensity in the right frontal deep white matter
# appears similar compared to recent prior exam.  No focus of new intracranial
# hemorrhage, large mass, mass effect, edema, or hydrocephalus is detected.
# There is preservation of gray-white matter differentiation.  The basal
# cisterns appear patent.  Mild white matter hypodensity is likely secondary to
# sequela of chronic small vessel ischemic disease.  Dense bilateral basal
# ganglia mineralization is seen.  The visualized portions of the paranasal
# sinuses and mastoid air cells appear well aerated.  No acute bony abnormality
# is detected.
#
# IMPRESSION:  Stable tiny focus of hyperdensity in the right frontal centrum
# semiovale white matter; no new hemorrhage.
#
# SINGLE FRONTAL VIEW OF THE CHEST
#
# REASON FOR EXAM:  History of COPD, hypoxia and dyspnea.
#
# Comparison is made with prior study ___.
#
# Cardiomediastinal contours are unchanged with cardiac size top normal.  Mild
# interstitial pulmonary edema is unchanged.  The patient has known COPD.  There
# is no pneumothorax.  If any there is a small left effusion.
#
# PORTABLE CHEST OF ___
#
# No prior chest radiographs for comparison.  Comparison is made to a scout
# image of the lower chest from a prior CT abdomen study of ___.
#
# FINDINGS:  Tip of endotracheal tube terminates 4.3 cm above the carina, and
# the cuff of the tube is slightly overdistended.  Widening of cardiomediastinal
# contours may reflect a combination of cardiovascular distention as well as
# mediastinal lipomatosis given the presence of a large amount of fat
# surrounding the heart on prior CT abdomen ___.  Bilateral
# perihilar airspace opacities involving the right lung to a greater degree than
# the left may reflect pulmonary edema, multifocal aspiration or infectious
# pneumonia.  Probable small right pleural effusion as well as a mild elevation
# of adjacent right hemidiaphragm.  No visible pneumothorax.
#
# EXAMINATION:  CHEST (PORTABLE AP)
#
# INDICATION:  ___ year old woman with respiratory failure  // pulmonary edema
#
# TECHNIQUE:  Chest single
#
# COMPARISON:  None
#
# FINDINGS:
#
# Endotracheal tube tip is 1.2 cm above carina.  Bilateral pleural effusions.
# Bilateral perihilar opacities, favor pulmonary edema.  Left basilar
# consolidation, likely atelectasis.  Heart size at the upper limits are normal.
# No pneumothorax.
#
# IMPRESSION:
#
# ETT 1.2 cm above carina.  Bilateral pleural effusions.  Perihilar opacities,
# favor pulmonary edema.  Left basilar consolidation, likely atelectasis.
#
# INDICATION:  ___ year old man with 8mm obstructing right ureteral stone and
# sepsis // Obstructing right ureteral stone, sepsis. Needs decompression.
#
# COMPARISON:  Comparison is made to is ct abdomen performed same day
#
# TECHNIQUE:   OPERATORS: Dr. ___ radiology fellow) and Dr.
# ___ radiology attending) performed the procedure. The
# attending, Dr. ___ was present and supervising throughout the procedure.
# ANESTHESIA: Moderate sedation was provided by administrating divided doses of
# 100 mcg of fentanyl and 2 mg of midazolam throughout the total intra-service
# time of 70 min during which the patient's hemodynamic parameters were
# continuously monitored by an independent trained radiology nurse. 1% lidocaine
# was injected in the skin and subcutaneous tissues overlying the access site.
# MEDICATIONS: Fentanyl calmer side, lidocaine. Patient is scheduled meropenem
# dose was given immediately prior to arrival.
# CONTRAST: 25 ml of Optiray contrast.
# FLUOROSCOPY TIME AND DOSE: 10.5 min, 904 cGy-cm2
#
# PROCEDURE:  1. Right ultrasound guided renal collecting system access.
# 2. Right nephrostogram.
# 3. 8 nephrostomy tube placement.
# PROCEDURE DETAILS: Following the discussion of the risks, benefits and
# alternatives to the procedure, written informed consent was obtained from the
# patient. The patient was then brought to the angiography suite and placed
# supine on the exam table. A pre-procedure time-out was performed per ___
# protocol. The right flank was prepped and draped in the usual sterile fashion.
# After the injection of 5 cc of 1% lidocaine in the subcutaneous soft tissues,
# the right renal collecting system was accessed through a posterior inter polar
# calyx (patient has had a prior lower pole partial nephrectomy) under
# ultrasound guidance using a 21 gauge Cook needle. Ultrasound images of the
# access were stored on PACS. Prompt return of urine confirmed appropriate
# positioning. Injection of a small amount of contrast outlined a dilated renal
# collecting system. Under fluoroscopic guidance, a Nitinol wire was advanced
# into the renal collecting system. After a skin ___, the needle was exchanged
# for an Accustick sheath. One the tip of the sheath was in the collecting
# system; the sheath was advanced over the wire, inner dilator and metallic
# stiffener. The wire and inner dilator were then removed and diluted contrast
# was injected into the collecting system to confirm position. A ___ wire was
# advanced through the sheath and coiled in the collecting system. The sheath
# was then removed and a 8 ___ nephrostomy tube was advanced into the renal
# collecting system. The wire was then removed and the pigtail was formed in the
# collecting system. Contrast injection confirmed appropriate positioning. The
# catheter was then flushed, 0 silk stay sutures applied and the catheter was
# secured with a Stat Lock device and sterile dressings. The catheter was
# attached to a bag.
# The patient had no immediate complications.
#
# FINDINGS:
#
# 1.  Minimal right hydronephrosis with  contrast flowing distally into the
# bladder .
# 2.  Successful placement of right PCN
#
# IMPRESSION:
#
# Successful placement of 8 ___ nephrostomy on the right.
#
# INDICATION:  ___ year old man with PICC  // Pt had a L PICC,46cm ___ ___
# Contact name: ___: ___
#
# TECHNIQUE:  AP portable chest radiograph
#
# COMPARISON:  ___ from earlier in the day
#
# FINDINGS:
#
# Interval placement of a left PICC line, which extends across midline however
# is looped back on itself projecting along the right vertebral bodies.  The tip
# of the endotracheal tube projects 3.8 cm from the carina.
#
# Increasing patchy and confluent opacities in the right lung as well as a new
# diffusely mildly increased airspace opacities in the left lung.  The opacities
# in the right lung may be partly secondary to an enlarging right pleural
# effusion.  The contour of the right cardiomediastinal silhouette are
# unchanged.
#
# IMPRESSION:
#
#
# 1. Mal-positioned left PICC as described above.  This finding was communicated
# to and acknowledged by ___ at 18h25 by ___, MD
# 2. Interval intubation with the tip of the endotracheal tube projecting over
# the mid thoracic trachea
# 3. Increasing bilateral airspace opacities may be secondary to pulmonary edema
# and/or multifocal infection.  Additionally there is an increased right pleural
# effusion.
#
# PORTABLE CHEST ___
#
# COMPARISON:  ___ radiograph.
#
# FINDINGS:  Cardiomegaly is accompanied by pulmonary vascular congestion and a
# widespread reticulation and ground-glass opacities which may be due to a
# pulmonary edema, opportunistic infection, or pulmonary hemorrhage.  Improved
# opacity at left lung base compared to ___ with residual opacity
# likely corresponding to known pleural lesion, better evaluated on recent CT,
# as well as a small left pleural effusion and adjacent atelectasis.
#
# INDICATION:  ___ male with ST elevation myocardial infarction, status
# post intra-aortic balloon pump device.  Currently, in respiratory distress.
#
# COMPARISON:  None available.
#
# TECHNIQUE:  Single AP portable supine chest radiograph.
#
# FINDINGS:  There is prominent bilateral perihilar opacity and peripheral
# Kerley B lines consistent with pulmonary edema most likely secondary to
# failure.  No pleural effusions are seen.  There is no cardiomegaly.  Pleural
# surfaces are unremarkable and there is no pneumothorax.
#
# IMPRESSION:  Pulmonary edema secondary to heart failure.
#
# EXAMINATION:  CHEST (PORTABLE AP)
#
# INDICATION:  ___ year old man with ESRD on HD here with cholangitis and
# possible cholecystitis, hypoxic requiring 3L NC.  // Eval for volume overload
# vs. other acute cardiopulmonary process.     Eval for volume overload vs.
# other acute cardiopulmonary process.
#
# IMPRESSION:
#
# No previous images.  There are intact midline sternal wires.  Enlargement of
# the cardiac silhouette with indistinctness of pulmonary vessels consistent
# with elevated pulmonary venous pressure.  Prominence of central pulmonary
# vessels could be a manifestation of substantial central edema or pulmonary
# arterial hypertension.
# Bibasilar opacifications most likely represent atelectasis.
#
# EXAMINATION:  CHEST (PORTABLE AP)
#
# INDICATION:  ___ year old woman s/p TAVR  // eval for ETT postition,
# pneumothoraces s/p TAVR      eval for ETT postition, pneumothoraces s/p TAVR
#
# IMPRESSION:
#
# In comparison with the study ___, following cardiac surgery the tip of
# the endotracheal tube lies approximately 3 cm above the carina.  Nasogastric
# tube extends well into the stomach.  Left chest tube is in place and there is
# no definite pneumothorax.
# Opacification at the left base is consistent with volume loss in the lower
# lobe probable small effusion.
# There is suggestion of some opacification in the right upper zone, which could
# represent aspiration in the appropriate clinical setting.
#
# EXAMINATION:  DX CHEST PORT LINE/TUBE PLCMT 1 EXAM
#
# INDICATION:  ___ year old woman s/p Tracheobronchoplasy, ETT, R chest tube  //
# Eval for PTX, ETT placement
#
# TECHNIQUE:  Chest single view
#
# COMPARISON:  ___
#
# FINDINGS:
#
# Endotracheal tube tip in good position.  Postoperative change cervical spine.
# Right chest tube.  Small volume right chest wall, low neck subcutaneous
# emphysema.  Shallow inspiration.  Bilateral perihilar, basilar opacities,
# likely atelectasis.  Suggestion of small pleural effusions.  Surgical clips
# left hilum.  No pneumothorax.
#
# IMPRESSION:
#
# Postoperative changes.
# Small volume subcutaneous emphysema.
# Perihilar, basilar opacities, likely atelectasis.
# Suggestion of small pleural effusions
#
# CHEST RADIOGRAPH
#
# INDICATION:  Hypercarbic respiratory failure, evaluation.
#
# COMPARISON:  ___.
#
# FINDINGS:  As compared to the previous radiograph, there is no relevant
# change.  Constant monitoring and support devices, constant relatively low lung
# volumes and moderate cardiomegaly.  Mild bilateral pleural effusions with
# signs of mild-to-moderate fluid overload and areas of atelectasis at both lung
# bases.
#
# EXAMINATION:  CHEST (PORTABLE AP)
#
# INDICATION:  ___ year old man with pulmonary edema, CHF, p/w sepsis shock  //
# ?worsening pulmonary edema ?acute intra pulm/cardiac process      ?worsening
# pulmonary edema ?acute intra pulm/cardiac process
#
# COMPARISON:  H
#
# IMPRESSION:
#
# Mild asymmetric pulmonary edema has improved slightly since ___ one.
# There may be a region of consolidation at the right base which has developed
# over the past 24 hr.  Conventional radiographs would be helpful to see if
# there is right lower lobe pneumonia.  Region of chronic abnormality in the
# left upper lobe is highlighted by the edema.  Mild cardiomegaly stable.
# Pleural effusions small if any.  Right jugular line ends in the mid SVC.  No
# pneumothorax.
#
# REASON FOR EXAMINATION:  Evaluation of the patient after intubation.
#
# AP radiograph of the chest was reviewed in comparison to prior study obtained
# ___ at 11:00 p.m. (approximately two hours earlier).
#
# The patient was intubated with the ET tube tip being almost 3 cm above the
# carina.  The right internal jugular line tip is at the level of mid SVC.  The
# NG tube tip is in the stomach.  Heart size and mediastinum are grossly
# unchanged since the patient is after median sternotomy and CABG.  Left basal
# linear opacities are unchanged, most likely representing scarring versus
# atelectasis.
#
# EXAMINATION:  CHEST (PORTABLE AP)
#
# INDICATION:  ___ year old man with respiratory failure and trach  // eval for
# interval change      eval for interval change
#
# COMPARISON:  Comparison to ___ at 11:22
#
# FINDINGS:
#
# Portable chest radiograph ___ at 04:54 is submitted.
#
# IMPRESSION:
#
# Tracheostomy tube and dual lumen right internal jugular central line unchanged
# in position.  Overall cardiac mediastinal contours are likely unchanged given
# marked patient rotation on the current study.  Left apical postsurgical
# changes and nodular opacities are stable.  Right medial lung base opacity
# likely reflects atelectasis, although pneumonia cannot be entirely excluded.
# No obvious pulmonary edema.  No large effusions.  Left glenohumeral
# degenerative joint changes.
#
# HISTORY:  Cardiac surgery.
#
# FINDINGS:  In comparison with the preoperative study, there are intact midline
# sternal wires in place.  The tip of the endotracheal tube appears to lie
# approximately 5.5 cm above the carina.  Right IJ Swan-Ganz catheter tip is in
# the right atrium.  Nasogastric tube extends to the upper stomach, with the
# side hole above the cardioesophageal junction.  Bilateral chest tubes are in
# place.  There is a small apical pneumothorax on the right.  Mild
# indistinctness of pulmonary vessels consistent with elevated pulmonary venous
# pressure.
#
# IMPRESSION:  Small right apical pneumothorax with high NG tube and some
# vascular congestion.
#
# EXAMINATION:  CHEST PORT. LINE PLACEMENT
#
# INDICATION:  ___ year old man with likely PE, now s/p L IJ CVC placement  // ?
# L IJ CVL placement   Contact name: ___: ___     ? L IJ CVL
# placement
#
# IMPRESSION:
#
# In comparison with the earlier study of this date, there is an placement of a
# left IJ catheter that extends to the mid to lower portion of the SVC.
# Substantial opacification persists at the left base, most likely related to
# atelectasis and small effusion.  The questioned increased opacification at the
# left apex is no longer seen and was a technical artifact.
#
# EXAMINATION:  CHEST (PORTABLE AP)
#
# INDICATION:  ___ year old man with heavy smoking history, tachypnea  //
# Evaluate for infection, pulmonary edema      Evaluate for infection, pulmonary
# edema
#
# IMPRESSION:
#
# No previous images.  Low lung volumes accentuate the prominence of the
# transverse diameter of the heart.  Mild tortuosity of the descending aorta.
# There may be mild elevation of pulmonary venous pressure, but no evidence of
# pleural effusion or acute focal pneumonia.
#
# HISTORY:  Depression hypertension and prior CVA status post overdose on
# medications presenting to the ICU with asymmetric pupils.
#
# TECHNIQUE:  Contiguous axial MDCT images were obtained of the head without
# contrast.  Thin-section bone algorithm images were obtained.
#
# DLP: 914.73 mGy-cm.
#
# COMPARISON:  None available.
#
# FINDINGS:
#
# The study is mildly limited by motion.  There is no hemorrhage, edema, mass
# effect or acute large territory infarct.  A chronic lacune is noted in the
# right basal ganglia.  Prominent ventricles and sulci are suggestive of
# age-related involutional change.  Areas of confluent subcortical hypodensity
# are compatible with chronic small vessel ischemic disease.  The basal cisterns
# are patent and there is preservation of gray-white matter differentiation.  No
# fracture is identified.  Mucosal wall thickening and partial fluid
# opacification is noted in bilateral maxillary sinuses, sphenoid air cells,
# ethmoid air cells and frontal ethmoidal recesses and frontal sinuses.  The
# middle ear cavities and mastoid air cells are clear.  The globes are intact.
# Atherosclerotic calcifications are noted in the carotid siphons.
#
# IMPRESSION:
#
# No acute intracranial process.
#
# If concern for acute ischemia persists, MRI is recommended given its greater
# sensitivity for acute ischemic lesions if no contraindications exist.
#
#
# AP CHEST, 5:47 P.M. ON ___
#
# HISTORY:  ___ man with severe aortic stenosis.
#
# IMPRESSION:  AP chest compared to ___:
#
# Moderate cardiomegaly and severe pulmonary vascular congestion have worsened
# and mild pulmonary edema is new.  Pleural effusions are small if any.  No
# pneumothorax.
#
# EXAMINATION:  CHEST PORT. LINE PLACEMENT
#
# INDICATION:  ___ year old man s/p AVR/CABG  // FAST TRACK EARLY EXTUBATION
# CARDIAC SURGERY   Contact name: ___: ___     FAST TRACK
# EARLY EXTUBATION CARDIAC SURGERY
#
# IMPRESSION:
#
# In comparison with the study of ___, there has been a cardiac surgery
# procedure performed with intact midline sternal wires.  Endotracheal tube tip
# lies approximately 2.9 cm above the carina.  Right IJ Swan-Ganz catheter is in
# the proximal right pulmonary artery.  Nasogastric tube extends into the
# stomach.  Chest tube is in place on the left with no evidence of pneumothorax.
# Postsurgical changes are seen on the left consistent with atelectasis and
# effusion.
#
# EXAMINATION:
# CT HEAD W/O CONTRAST
#
# INDICATION:  Left occipital/parietal intraparenchymal hemorrhage. Evaluate for
# interval change.
#
# TECHNIQUE:  Contiguous axial images of the brain were obtained without the
# administration of IV contrast. Coronal and sagittal as well as thin
# bone-algorithm reconstructed images were obtained.
#
# DOSE:  DLP: 1003.42 mGy-cm;
# CTDIvol:  53.59 mGy
#
# COMPARISON:  None. Outside study exams are not available in PACS for
# comparison at the time of this dictation.
#
# FINDINGS:
#
# There is a large left occipital-parietal intraparenchymal hemorrhage measuring
# approximately 48 x 32 x 61 mm. There is surrounding edema and mass effect,
# with effacement of the adjacent sulci, compression of the adjacent occipital
# horn of the left lateral ventricle, and approximately 3 to 4 mm of rightward
# shift of the normal midline structures.  No other foci of hemorrhage are
# identified.
#
# Other than from the mass effect of the hemorrhage, the ventricles and sulci
# are normal in size and configuration. There is no evidence of hydrocephalus or
# entrapment. The basal cisterns are patent. Atherosclerotic calcifications are
# noted in the intracranial arteries.
#
# No fracture is identified. The visualized paranasal sinuses, mastoid air
# cells, and middle ear cavities are clear. The soft tissues and orbits are
# unremarkable.
#
# IMPRESSION:
#
# Large left occipital-parietal intraparenchymal hemorrhage, as described above.
# The prior exams are not available for comparison at this time.
#
# EXAMINATION:  CHEST (PORTABLE AP)
#
# INDICATION:  ___ year old woman with STEMI, cardiogenic shock. intubated  //
# effusions. ETT position      effusions. ETT position
#
# IMPRESSION:
#
# Compared to prior chest radiographs ___.
#
# Lung volumes are lower despite tracheal intubation.  ETT tip is no less than
# 15 mm from the carina the actual distance is distorted by patient positioning.
# Trachea is not actually quite short and ETT positioning will require periodic
# radiographic confirmation.
#
# Poor definition of the lower tracheal AND right bronchial airway could be due
# to retained secretions.  Clinical correlation advised.  No definite pulmonary
# edema or evidence of pneumonia.  New small left pleural effusion is likely.
# No pneumothorax.
#
# REASON FOR EXAMINATION:  Evaluation of the patient with diastolic congestive
# heart failure, decompensated.
#
# Portable AP radiograph of the chest was reviewed in comparison to ___.
#
# Heart size and mediastinum are stable.  Widespread parenchymal opacities
# giving the perihilar centering are most likely consistent with pulmonary edema
# that appears to be minimally improved since the prior study.  No pneumothorax
# is seen.  There is small amount of pleural effusion.  No evidence of new
# consolidation is demonstrated to suggest interval development of infectious
# process.
#
# EXAMINATION:  CHEST (PORTABLE AP)
#
# INDICATION:  ___ year old man with ETT  // interval changes
#
# TECHNIQUE:  Portable AP chest radiograph.
#
# COMPARISON:  Chest radiograph ___
#
# FINDINGS:
#
# An endotracheal tube is in-situ, the tip terminates 4 cm above the level of
# the carina.  This is unchanged compared to the prior study.  A left-sided PICC
# is in-situ, the tip terminates in the mid SVC.  A right internal jugular
# catheter is in-situ, also terminating in the mid SVC.  A nasogastric tube is
# in-situ, the tip is not visualized but the side port is below the left
# hemidiaphragm.  Increased opacity at the left lung base with partial
# silhouetting of the left hemidiaphragm likely due to a atelectasis but
# superimposed infection cannot be excluded.  No definite effusion seen.
# Catheter tubing projects over the upper abdomen, this is not clearly localized
# on the current study but given the course of the tubing likely resides on the
# patient's skin.
#
# TYPE OF EXAMINATION:  Chest AP portable single view.
#
# INDICATION:  ___ female patient status post intubation, assess for
# tube placement.
#
# FINDINGS:  AP single view of the chest has been obtained with patient in
# supine position.  An ETT has been placed, seen to terminate in the trachea 5
# cm above the level of the carina.  No pneumothorax is seen.  Heart size may be
# slightly enlarged but difficult to assess because of obscuring high-positioned
# diaphragms.  Crowded appearance of lower lobe pulmonary vasculature but no
# conclusive evidence for acute pulmonary infiltrates or pneumothorax on this
# portable chest examination.  Our records do not include a preceding chest
# examination available for comparison.
#
# EXAMINATION:  CHEST (PORTABLE AP)
#
# INDICATION:  ___ year old man with altered mental status  // Eval for pneumonia
# Eval for pneumonia
#
# IMPRESSION:
#
# Comparison to ___.  Previous signs of pulmonary edema have cleared.
# Moderate cardiomegaly.  Mild elongation of the descending aorta.  No pleural
# effusions.  No current evidence of pneumonia.
#
# EXAMINATION:  FOOT 2 VIEWS LEFT
#
# INDICATION:  ___ year old woman with dry gangrene  // assess for osteomyelitis,
# subcutaneous air
#
# TECHNIQUE:  THREE VIEWS OF THE LEFT FOOT
#
# COMPARISON:  Left foot radiograph ___
#
# FINDINGS:
#
# The patient is status post amputation at the level of the proximal
# metatarsals.  There is diffuse osteopenia, which limits evaluation for non
# displaced fractures.  There is soft tissue thickening and possible edema at
# the amputation site.  No definite erosive changes or periosteal reaction.
# Vascular calcifications are noted.  There is a calcaneal spur.
#
# IMPRESSION:
#
# There is diffuse osteopenia.  No definite radiographic findings to suggest
# osteomyelitis, however, evaluation is limited in its if persistent clinical
# concern MRI is recommended.
#
# EXAMINATION:  CHEST (PORTABLE AP)
#
# INDICATION:  ___ year old man with fever  // lung pathology      lung pathology
#
# COMPARISON:  Prior chest radiographs ___ and ___ at 04:57.
#
# IMPRESSION:
#
# Significant atelectasis persists in the left lower lobe, but probably
# improved, since leftward mediastinal shift is less pronounced.  Atelectasis at
# the right base is mild.  Upper lungs are clear.  Small left pleural effusion
# is present.  The small gas bubble projecting over the cardiac silhouette is
# presumably in the stomach beneath the elevated left hemidiaphragm, but it
# would be good to confirm that with conventional PA and lateral chest
# radiographs as soon as feasible.
#
# RECOMMENDATION(S):  Conventional PA and lateral chest radiographs, as soon as
#
# EXAMINATION:  ULTRASOUND INTERVENTIONAL PROCEDURE
#
# INDICATION:  ___ year old man with segment 2 abscess // eval for drainage of
# collection please
#
# COMPARISON:  CT ___ at 09:12am, ultrasound ___ at 07:04am
#
# PROCEDURE:  Ultrasound-guided drainage of intrahepatic fluid collection.
#
# OPERATORS:  Dr. ___, radiology fellow and Dr. ___,
# attending radiologist. Dr. ___ the entire procedure in the ICU at
# the patient's bedside.
#
# TECHNIQUE:  The risks, benefits, and alternatives of the procedure were
# explained to the patient. After a detailed discussion, informed written
# consent was obtained. A pre-procedure timeout using three patient identifiers
# was performed per ___ protocol.
#
# The procedure was performed at the bedside in the surgical ICU. The patient
# was supine. Limited preprocedure ultrasound was performed to localize the
# collection. Based on the ultrasound findings, an appropriate skin entry site
# for the drain placement was chosen. The site was marked. Local anesthesia was
# administered with 1% Lidocaine solution.
#
# Using continuous sonographic guidance, an ___ Exodus drainage catheter
# was advanced via trocar technique into the collection. Once the catheter tip
# was clearly seen within the fluid collection, the trocar and metal stiffener
# were removed and the pigtail was deployed. The position of the pigtail was
# confirmed within the collection via ultrasound.
#
# Approximately 20 cc of sanguinous fluid with purulent debris was drained with
# a sample sent for microbiology evaluation. The catheter was secured by a
# StatLock. The catheter was attached to a suction bulb. Sterile dressing was
# applied.
#
# The procedure was tolerated well, and there were no immediate post-procedural
# complications.
#
# SEDATION:  Divided doses of 100 mcg fentanyl were administered by the ICU
# nurse throughout the procedure during which patient's hemodynamic parameters
# were continuously monitored by the ICU nurse.
#
# FINDINGS:
#
# Targeted ultrasound demonstrates a heterogeneous appearing intrahepatic fluid
# collection in hepatic segment II, unchanged from ___ at 07:04 am.
#
# IMPRESSION:
#
# US-guided placement of ___ pigtail catheter into the intrahepatic abscess
# in segment II. A sample was sent for microbiology evaluation.
#
# NOTIFICATION:  The findings were discussed by Dr. ___ with Dr. ___
# ___ (surgery) in person on ___ at 5:25 ___, upon procedure completion.
#
# EXAMINATION:  CHEST (PORTABLE AP)
#
# INDICATION:  ___ year old woman with STEMI now with increasing leukocytosis  //
# evidence of new infiltrate      evidence of new infiltrate
#
# IMPRESSION:
#
# Comparison to ___.  No relevant change.  Vertebral fixation devices.
# Normal lung volumes.  Mild cardiomegaly without pulmonary edema.  No pleural
# effusions.  No pneumonia.
#
# CHEST RADIOGRAPH
#
# INDICATION:  PICC line placement.
#
# COMPARISON:  ___.
#
# FINDINGS:  As compared to the previous radiograph, the patient has received a
# left-sided PICC line.  The tip of the line projects over the lower SVC.  No
# complications, in particular no pneumothorax.
#
# The lung volumes have decreased.  There currently is mild to moderate fluid
# overload.  No pneumonia, no focal parenchymal opacities.  No larger pleural
# effusions.
#
# EXAMINATION:  CHEST (PORTABLE AP)
#
# INDICATION:  ___ year old man with esophageal leak s/p redo anastomosis  //
# eval for interval change
#
# TECHNIQUE:  Portable AP radiograph of the chest.
#
# COMPARISON:  ___.
#
# FINDINGS:
#
# A new right apical chest tube has been placed.  A nasogastric tube enters the
# neo-esophagus to terminate in the gastric remnant.  The endotracheal tube
# terminates at the level of the clavicles.  New right surgical skin staples are
# in place.  The previous moderate right hydropneumothorax has substantially
# improved.  Bilateral interstitial opacities are most likely due to pulmonary
# edema.  Band-like opacities in both mid lung zones are likely due to
# atelectasis.  There is a new small amount of right chest wall subcutaneous
# emphysema.
#
# IMPRESSION:
#
# Substantial interval improvement in previous moderate right hydropneumothorax.
#
# EXAMINATION:  CHEST (PORTABLE AP)
#
# INDICATION:  ___ year old man with ESRD s/p transplant p/w flu and PNA,
# recently intubated  // OGT in place?
#
# COMPARISON:  ___
#
# IMPRESSION:
#
# The upper enteric tube terminates in the proximal stomach, the side port is at
# the level of the gastroesophageal junction.  The tube should be advanced by
# approximately 10 cm.  The appearance of the lung parenchyma and the cardiac
# silhouette is unchanged as compared to the previous examination.
#
# SINGLE FRONTAL VIEW OF THE CHEST
#
# REASON FOR EXAM:  Assess Dobbhoff placement.
#
# Comparison is made with prior study ___.
#
# Dobbhoff tube tip is in the antrum of the stomach, less likely in the first
# portion of the duodenum.  There are low lung volumes.  There is moderate
# cardiomegaly and widened mediastinum.  There is mild vascular congestion.
# There is no pneumothorax or pleural effusion.
#
# EXAMINATION:  CHEST (PORTABLE AP)
#
# INDICATION:  ___ year old woman with intermittent SOB  // acute process
#
# COMPARISON:  ___
#
# IMPRESSION:
#
# As compared to the previous radiograph, a minimal right pleural effusion is
# better seen than on the previous image.  Mild cardiomegaly. Retrocardiac
# atelectasis. No other changes.
#
# EXAMINATION:  CHEST (PORTABLE AP)
#
# INDICATION:  ___ year old woman with severe AS post TAVR  // ?position of
# pacing wire      ?position of pacing wire
#
# COMPARISON:  Preoperative chest radiograph on ___.
#
# IMPRESSION:
#
# Moderate to severe pulmonary edema is new.  TAVR and ascending aortic endo
# graft are in tandem.  Heart size normal.  Small pleural effusions are new.  No
# pneumothorax.  No mediastinal widening.
#
# Right transjugular temporary pacer lead ends in the mid right atrium.
#
# ET tube at the thoracic inlet, could be advanced 2 cm for more secure
# positioning.  Nasogastric tube passes into the stomach and out of view.
#
# NOTIFICATION:  Dr. ___ reported the findings to ___  by telephone on
# ___ at 5:00 ___, 1 min after the findings were recognize.  .
#
# INDICATION:  Post-right subclavian line placement, question of pneumothorax.
#
# COMPARISON:  Chest radiograph done two hours earlier.
#
# FINDINGS:  One portable upright view of the chest.  New right subclavian line
# ends in the mid-to-low SVC.  There is a new moderate-sized right pneumothorax
# with no evidence of tension.  Compared to the most recent study, no change in
# bilateral opacifications with lower lobe predominance.  No pleural effusion.
# The cardiac, mediastinal, and hilar contours are stable.  The ET tube ends 7.5
# cm from the carina, and an enteric tube is seen with its tip not imaged.
#
# IMPRESSION:  New right subclavian line placement with moderate-sized right
# apical pneumothorax.  Otherwise unchanged compared to most recent study done
# two hours earlier.
#
# These findings were discussed with the covering team at 2:30pm on ___ by
# telephone.
#
# SINGLE FRONTAL VIEW OF THE CHEST
#
# REASON FOR EXAM:  Status post liver transplant.
#
# ET tube is in standard position.  The tip is 3.4 cm above the carina.  Left
# subclavian catheter tip is in the upper SVC.  There is no pneumothorax.
# Swan-Ganz catheter tip is in the main pulmonary artery.  NG tube tip is out of
# view below the diaphragm.  There is a right IJ catheter sheath, with tip at
# the distal right IJ.  Multiple drains are present in the right upper quadrant.
# There are low lung volumes.  Mild-to-moderate vascular congestion.  Bibasilar
# atelectases are larger on the left side.  Right pleural effusion is small.
# Multiple surgical clips projecting the left medial hemithorax.  There are skin
# staples in the upper abdomen.
#
# EXAMINATION:  CHEST (PORTABLE AP)
#
# INDICATION:  ___ year old woman with pna s/p intubation  // eval for pna;
# intubated      eval for pna; intubated
#
# IMPRESSION:
#
# Compared to chest radiographs ___ through ___.
#
# ET tube in standard placement.  New right jugular line ends in the upper right
# atrium, approximately one cm below the estimated location of the superior
# cavoatrial junction.  New the spinal stabilization hardware in place.
#
# Stomach is moderately to severely distended with air and fluid.  No
# nasogastric tube in place.
#
# No pneumothorax or appreciable pleural effusion.  Moderate left basal
# atelectasis has improved.  Heart size is normal.
#
# REASON FOR EXAMINATION:  Evaluation of the patient after cardiogenic shock and
# new Swan-Ganz catheter placement.
#
# AP radiograph of the chest was reviewed in comparison to ___.
#
# The Swan-Ganz catheter tip terminates most likely at the origin of the right
# upper lobe pulmonary artery.  The right PICC line tip is at the cavoatrial
# junction.  Heart size and mediastinum are unchanged.  Vascular congestion is
# present mostly involving upper lobes.
#
# EXAMINATION:  DX CHEST PORTABLE PICC LINE PLACEMENT
#
# INDICATION:  ___ year old man with GVHD, pneumonia, CHF  // interval change,
# PICC position      interval change, PICC position
#
# IMPRESSION:
#
# Compared to chest radiographs since ___ most recently ___.
#
# Lung volumes are very low, mildly improved since ___.  Right lower lobe is
# substantially atelectatic.  Dense consolidation in the left lower lobe could
# be atelectasis also, unchanged, but pneumonia is a possibility.  Cardiac
# silhouette and mediastinal veins are mildly enlarged, but there is no
# pulmonary edema.
#
# Left PIC line passes into the right atrium, but the tip is indistinct.
# Conventional radiographs will probably be required for localization.
#
# RECOMMENDATION(S):
# Conventional radiographs will probably be required for PICC localization.
#
# SINGLE FRONTAL VIEW OF THE CHEST
#
# REASON FOR EXAM:  Assess Swan-Ganz.
#
# Comparison is made with prior study ___ in the morning.
#
# Right Swan-Ganz catheter tip is in the segmental branch in the right lower
# lobe, should be withdrawn approximately 6 cm for a more standard position.
# There is no pneumothorax.  There is mild cardiomegaly and low lung volumes.
# Bibasilar opacities, larger on the right, have minimally increased.
#
# INDICATION:  ___ year old woman with STEMI, now intubated post cath with pacer
# wire in place  // placement of pacer wire
#
# COMPARISON:  Radiographs from ___ at 06:40.
#
# IMPRESSION:
#
# There has been placement of a pacemaker wire from an inferior approach which
# projects over the right atrium.  Orogastric and endotracheal tubes are
# unchanged in position.  There is cardiomegaly, stable. There are small
# bilateral effusions.  No focal consolidation is seen.
#
# TYPE OF EXAMINATION:  Chest AP portable single view.
#
# INDICATION:  ___ female patient status post left ventricular assist
# device placement.  Assess for lines and ETT.
#
# FINDINGS:  AP single view of the chest has been obtained with patient in
# supine position.  Comparison is made with the next preceding portable AP
# single view chest examination of ___.  There is now status post
# recent sternotomy and cardiac intervention with new midline row of circular
# thoracotomy wires.  The patient is intubated, the ETT terminating in the
# trachea some 2 cm above the level of the carina.  Some withdrawal by 1-2 cm is
# recommended to avoid mechanical obstruction.  Previously described right-sided
# PICC line, permanent pacer in left anterior axillary position with evidence of
# biventricular electrodes with ECD and trans-coronary-venous stimulation appear
# unchanged.  Heart size is unaltered and pulmonary vascular congestive pattern
# not increased.  Other new instruments include a new right internal jugular
# approach sheath that apparently carries a Swan-Ganz catheter, the tip of which
# reaches the central portion of the pulmonary artery.  A large metallic tubular
# device (probably LVAD) is overlying the upper abdomen.  The most right-sided
# portion is overlying the area of right upper abdomen and probably aiming for
# connection with the inferior vena cava.  The left-sided portion of the device
# is overlying the left-sided diaphragm with the upper portion separated by an
# approximately 1-2 cm diastasis and also observes the presence of a large
# mediastinal drainage tube and a left-sided chest tube advanced from below.
# Again, there is no evidence of new pulmonary parenchymal infiltrates or
# significantly advanced pulmonary congestion and no pneumothorax exists in the
# apical area.  Referring physician, ___ was paged to discuss
# findings.  Subsequent referral was made to ___, who was paged at
# 4:45 p.m. to discuss detail of findings.
#
# AP CHEST 3:30 A.M. ON ___
#
# HISTORY:  A ___ man, bleeding after CABG.
#
# IMPRESSION:  AP chest compared to ___:
#
# Relative increase in the caliber of the cardiomediastinal silhouette is mild,
# but whether there is active bleeding needs to be determined from volumes of
# tube drainage.  Left upper lobe collapse persists.  There is no appreciable
# pleural effusion or pneumothorax.  Lines and tubes are in standard placements.
# No pneumothorax.
#
# INDICATION:  ___ year old man with SAH and L ICA aneurysm .  Coiling of L PCOMM
# aneurysm.
#
# COMPARISON:  None
#
# TECHNIQUE:  The patient was brought to the angio suite and positioned on the
# angio table.  General anesthesia was induced.  The patient was prepped and
# draped in usual sterile fashion a time-out was performed.  The right common
# femoral artery was localized using anatomic landmarks and a 6 ___ long
# sheath was placed using Seldinger technique and micro puncture kit.  A ___
# 2 diagnostic catheter was used to select the left vertebral artery.  AP and
# lateral views of the posterior intracranial circulation were obtained.  Next,
# the right common carotid artery was selected.  AP, lateral and oblique views
# of the right anterior intracranial circulation were obtained.  Next, the left
# internal carotid artery was selected.  AP and lateral views of the left
# anterior intracranial circulation were obtained.  3D rotational images were
# performed requiring post processing on an independent workstation under
# concurrent physician supervision and used in the interpretation and reporting
# of the procedure.  5000 units of intravenous heparin were given and the ACT
# was titrated to 250.  Under roadmap guidance the diagnostic catheter was
# exchanged for a Benchmark guide catheter.  Using the 3D rotational angiogram
# optimal working views were obtained.  Under roadmap guidance an SL 10 micro
# catheter was navigated over a synchro standard micro wire into the aneurysm.
# A series of coils were deployed.  Periodically AP and lateral focused views of
# the left anterior intracranial circulation were obtained.  At the end of the
# procedure the micro catheter was removed, global AP and lateral guide catheter
# angiograms were obtained, and the arteriotomy site was closed with Angio-Seal.
# DEVICES:  0.038" 150cm Angled Glidewire
# 0.035 x 150cm ___ Wire
# ___ x 100cm Sim2  .038 Glidecath
# 0.038 Angled Glidewire Exchange
# ___ .071 95cm Benchmark Delivery Catheter
# Synchro2 Standard 14 200cm Wire
# Excelsior SL-10 Pre-shaped 45, 2-Tip Microcath
# Target XL 360 Soft  9mm/30cm Coil
# Target XL 360 Soft  8mm/30cm Coil
# Target XL 360 Soft  7mm/20cm Coil
# Target XL 360 Soft  6mm/20cm Coil
# Target XL 360 Soft  6mm/20cm Coil
# Target XL Helical 5mm/15cm Coil
# Target XL Helical 5mm/15cm Coil
# ___ Angio Seal Evolution Closure Device
#
# PROCEDURE:
# 1. Coil embolization of ruptured left posterior communicating artery aneurysm.
#
# FINDINGS:
#
# Left vertebral artery:  The posterior intracranial circulation is
# unremarkable.  No evidence of vasospasm.
#
# Right common carotid artery:  The right carotid bifurcation is well visualized
# without significant arteriosclerotic disease of stenosis.  The right anterior
# intracranial circulation is unremarkable.  No evidence of vasospasm.
#
# Left internal carotid artery:  The left anterior intracranial circulation is
# notable for a 18 mm posterior communicating artery aneurysm.  No evidence of
# vasospasm.  After completion of coil embolization and the aneurysms completely
# obliterated consistent with ___ grade 1.
#
# IMPRESSION:
#
# ___ grade 1 coil embolization of ruptured left posterior communicating
# artery aneurysm.
#
# I, ___, participated in this procedure.  I, ___
# ___, was present for the entirety of this procedure and supervised all
# critical steps.
#
#  I, ___, have reviewed the report and agree with the fellow's
# findings.
#
# CLINICAL HISTORY:  Central venous line placed, check position.
#
# The right subclavian line has gone into the internal jugular vein and its tip
# cannot be seen.
#
# Focal opacities are again noted within both the right and left lobes and a
# right effusion is likely present.  These could represent a patchy
# bronchopneumonia rather than resolving failure.
#
# IMPRESSION:  Central line in right neck.
#
# EXAMINATION:  CHEST (PORTABLE AP)CHEST (PORTABLE AP)i
#
# INDICATION:  ___ year old man with schizoaffective disorder intubated for
# hypoxemic respiratory distress  // ET tube and NG tube position
#
# COMPARISON:  Chest radiographs ___ through ___ at 04:54.
#
# IMPRESSION:
#
# New endotracheal tube in standard position. Nasogastric tube passes into the
# upper stomach and would need to be advanced 5 cm to move all the side ports
# beyond the gastroesophageal junction. Lung volumes have improved generally,
# particularly in the right lower lobe below the right hemidiaphragm is still
# elevated. Residual consolidation in the lower lobe could be atelectasis or
# pneumonia.  Heart size normal has decreased substantially since earlier in the
# day.  Left PIC line ends at the origin of the SVC
#
# EXAMINATION:  CHEST PORT. LINE PLACEMENT
#
# INDICATION:  ___ year old woman s/p CABG. Please page ___ at ___
# with abnormalities.  // FAST TRACK EXTUBATION CARDIAC SURGERY, ?line
# placement, r/o PTX/Effusion  Contact name: ___: ___    FAST
# TRACK EXTUBATION CARDIAC SURGERY, ?line placement, r/o
#
# IMPRESSION:
#
# In comparison with the preoperative study ___, there has been a CABG
# procedure with intact midline sternal wires. Endotracheal tube measures
# approximately 4.5 cm above the carina.  Right IJ catheter is difficult to
# evaluate, but appears to extend to the lower SVC. Nasogastric tube extends
# into the stomach and a left chest tube is in place without evidence of
# pneumothorax. Atelectatic changes are seen at the bases.
#
# PORTABLE CHEST FILM ___ AT 1:20 pm
#
# CLINICAL INDICATION:  ___ with fever and cough, concern for pneumonia.
#
# Comparison to ___ and ___.
#
# Portable upright chest film ___ at 1:20pm is submitted.
#
# IMPRESSION:
#
# 1.  Lungs are relatively well inflated.  There is a slight reticulonodular
# opacity along the medial right base which is not significantly changed but was
# not previously present in ___ and therefore could represent an acute
# infectious atypical process or patchy atelectasis.  Clinical correlation is
# advised.  Left lung is clear.  No pulmonary edema or pneumothorax.  Overall
# cardiac and mediastinal contours are stable.
#
# EXAMINATION:  CHEST (PA AND LAT)
#
# INDICATION:  ___ year old man with CHF presenting with volume overload, VT  //
# e/o pulm edema      e/o pulm edema
#
# COMPARISON:  Chest radiographs ___.
#
# IMPRESSION:
#
# Mild pulmonary edema has not cleared.  Opacification has developed at both
# lung bases consistent with combination of dependent edema and atelectasis than
# pneumonia is not excluded.  Severe cardiomegaly is long-standing.
#
# Pleural effusions are presumed, but not large.  No pneumothorax.  Left
# subclavian right ventricular defibrillator in standard placement.  ET tube,
# 2.5 cm from the carina with the chin down is acceptable.  Nasogastric drainage
# tube passes into the stomach and out of view.
#
# EXAMINATION:  CHEST (PORTABLE AP)
#
# INDICATION:  ___ year old man HD6 for GSW, inc WBC's and low-grade fever  //
# evaluate for PNA      evaluate for PNA
#
# IMPRESSION:
#
# Compared to chest radiographs ___.
#
# Lung volumes are extremely low, exaggerating what could be mild pulmonary
# edema and pulmonary vascular engorgement, and top-normal heart size.
# Bronchial cuffing is another indication of mild edema.  No focal consolidation
# is present to suggest pneumonia.
#
# No pneumothorax or pleural effusion.  Right central venous line ends close to
# the superior cavoatrial junction.
