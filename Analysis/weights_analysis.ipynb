# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 4 Modalities kl

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/final/kl/"  # Replace with your output directory
missingInd = False              # Set to True if missing modality was used
modeltype = "TS_CXR_Text_ECG"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL Over Epochs (subset)")
plt.xlabel("Epoch")
plt.ylabel("KL")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/final/kl/"  # Replace with your output directory
missingInd = True              # Set to True if missing modality was used
modeltype = "TS_CXR_Text_ECG"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL Over Epochs (subset)")
plt.xlabel("Epoch")
plt.ylabel("KL")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %% [markdown]
# # TS CXR ECG

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/final/kl/"  # Replace with your output directory
missingInd = False              # Set to True if missing modality was used
modeltype = "TS_CXR_ECG"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL Over Epochs (subset)")
plt.xlabel("Epoch")
plt.ylabel("KL")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/final/kl/"  # Replace with your output directory
missingInd = True              # Set to True if missing modality was used
modeltype = "TS_CXR_ECG"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * MI Over Epochs (subset)")
plt.xlabel("Epoch")
plt.ylabel("KL * MI")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %% [markdown]
# # TS CXR Text

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/final/kl/"  # Replace with your output directory
missingInd = False              # Set to True if missing modality was used
modeltype = "TS_CXR_Text"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL Over Epochs (subset)")
plt.xlabel("Epoch")
plt.ylabel("KL")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/final/kl/"  # Replace with your output directory
missingInd = True              # Set to True if missing modality was used
modeltype = "TS_CXR_Text"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL Over Epochs (subset)")
plt.xlabel("Epoch")
plt.ylabel("KL")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %% [markdown]
# # TS ECG Text

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/final/kl/"  # Replace with your output directory
missingInd = False              # Set to True if missing modality was used
modeltype = "TS_ECG_Text"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL Over Epochs (subset)")
plt.xlabel("Epoch")
plt.ylabel("KL")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/final/kl/"  # Replace with your output directory
missingInd = True              # Set to True if missing modality was used
modeltype = "TS_ECG_Text"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * MI Over Epochs (subset)")
plt.xlabel("Epoch")
plt.ylabel("KL * MI")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4 Modalities kl_mi

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/final/kl_mi/"  # Replace with your output directory
missingInd = False              # Set to True if missing modality was used
modeltype = "TS_CXR_Text_ECG"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * MI Over Epochs (subset)")
plt.xlabel("Epoch")
plt.ylabel("KL * MI")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/final/kl_mi/"  # Replace with your output directory
missingInd = True              # Set to True if missing modality was used
modeltype = "TS_CXR_Text_ECG"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * MI Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("KL * MI")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_cc/"  # Replace with your output directory
missingInd = False              # Set to True if missing modality was used
modeltype = "TS_CXR_Text_ECG"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * CC Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("KL * CC")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_cc/"  # Replace with your output directory
missingInd = True              # Set to True if missing modality was used
modeltype = "TS_CXR_Text_ECG"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * CC Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("KL * CC")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %% [markdown]
# # TS CXR ECG

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_mi/"  # Replace with your output directory
missingInd = False              # Set to True if missing modality was used
modeltype = "TS_CXR_ECG"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)
df_all = df_all[~df_all['modality'].isin(['text'])]

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * MI Over Epochs (subset)")
plt.xlabel("Epoch")
plt.ylabel("KL * MI")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_mi/"  # Replace with your output directory
missingInd = True              # Set to True if missing modality was used
modeltype = "TS_CXR_ECG"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)
df_all = df_all[~df_all['modality'].isin(['text'])]

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * MI Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("KL * MI")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_cc/"  # Replace with your output directory
missingInd = False              # Set to True if missing modality was used
modeltype = "TS_CXR_ECG"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)
df_all = df_all[~df_all['modality'].isin(['text'])]

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * CC Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("KL * CC")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_cc/"  # Replace with your output directory
missingInd = True              # Set to True if missing modality was used
modeltype = "TS_CXR_ECG"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)
df_all = df_all[~df_all['modality'].isin(['text'])]

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * CC Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("KL * CC")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %% [markdown]
# # TS CXR Text

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_mi/"  # Replace with your output directory
missingInd = False              # Set to True if missing modality was used
modeltype = "TS_CXR_Text"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)
df_all = df_all[~df_all['modality'].isin(['ecg'])]

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * MI Over Epochs (subset)")
plt.xlabel("Epoch")
plt.ylabel("KL * MI")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_mi/"  # Replace with your output directory
missingInd = True              # Set to True if missing modality was used
modeltype = "TS_CXR_Text"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)
df_all = df_all[~df_all['modality'].isin(['ecg'])]

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * MI Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("KL * MI")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_cc/"  # Replace with your output directory
missingInd = False              # Set to True if missing modality was used
modeltype = "TS_CXR_Text"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)
df_all = df_all[~df_all['modality'].isin(['ecg'])]

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * CC Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("KL * CC")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_cc/"  # Replace with your output directory
missingInd = True              # Set to True if missing modality was used
modeltype = "TS_CXR_Text"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)
df_all = df_all[~df_all['modality'].isin(['ecg'])]

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * CC Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("KL * CC")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %% [markdown]
# # TS ECG Text

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_mi/"  # Replace with your output directory
missingInd = False              # Set to True if missing modality was used
modeltype = "TS_ECG_Text"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)
df_all = df_all[~df_all['modality'].isin(['cxr'])]

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL Over Epochs (subset)")
plt.xlabel("Epoch")
plt.ylabel("KL")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_mi/"  # Replace with your output directory
missingInd = True              # Set to True if missing modality was used
modeltype = "TS_ECG_Text"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)
df_all = df_all[~df_all['modality'].isin(['cxr'])]

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * MI Over Epochs (subset)")
plt.xlabel("Epoch")
plt.ylabel("KL * MI")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_cc/"  # Replace with your output directory
missingInd = False              # Set to True if missing modality was used
modeltype = "TS_ECG_Text"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)
df_all = df_all[~df_all['modality'].isin(['cxr'])]

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * CC Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("KL * CC")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_cc/"  # Replace with your output directory
missingInd = True              # Set to True if missing modality was used
modeltype = "TS_ECG_Text"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)
df_all = df_all[~df_all['modality'].isin(['cxr'])]

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * CC Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("KL * CC")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()
