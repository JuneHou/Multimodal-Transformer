# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 4 Modalities

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_mi/"  # Replace with your output directory
missingInd = False              # Set to True if missing modality was used
modeltype = "TS_CXR_Text_ECG"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * MI Over Epochs (subset)")
plt.xlabel("Epoch")
plt.ylabel("KL * MI")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_mi/"  # Replace with your output directory
missingInd = True              # Set to True if missing modality was used
modeltype = "TS_CXR_Text_ECG"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * MI Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("KL * MI")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_cc/"  # Replace with your output directory
missingInd = False              # Set to True if missing modality was used
modeltype = "TS_CXR_Text_ECG"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * CC Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("KL * CC")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_cc/"  # Replace with your output directory
missingInd = True              # Set to True if missing modality was used
modeltype = "TS_CXR_Text_ECG"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * CC Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("KL * CC")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_cc/"  # Replace with your output directory
missingInd = True              # Set to True if missing modality was used
modeltype = "TS_CXR_Text_ECG"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * CC Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("KL * CC")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %% [markdown]
# # TS CXR ECG

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_mi/"  # Replace with your output directory
missingInd = False              # Set to True if missing modality was used
modeltype = "TS_CXR_ECG"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)
df_all = df_all[~df_all['modality'].isin(['text'])]

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * MI Over Epochs (subset)")
plt.xlabel("Epoch")
plt.ylabel("KL * MI")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_mi/"  # Replace with your output directory
missingInd = True              # Set to True if missing modality was used
modeltype = "TS_CXR_ECG"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)
df_all = df_all[~df_all['modality'].isin(['text'])]

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * MI Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("KL * MI")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_cc/"  # Replace with your output directory
missingInd = False              # Set to True if missing modality was used
modeltype = "TS_CXR_ECG"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)
df_all = df_all[~df_all['modality'].isin(['text'])]

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * CC Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("KL * CC")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 21
#      18         all_dfs.append(df)
#      20 # Combine all epochs
# ---> 21 df_all = pd.concat(all_dfs, ignore_index=True)
#      22 df_all = df_all[~df_all['modality'].isin(['text'])]
#      24 # === Plotting ===
#
# File /data/wang/junh/envs/flex-moe/lib/python3.10/site-packages/pandas/core/reshape/concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File /data/wang/junh/envs/flex-moe/lib/python3.10/site-packages/pandas/core/reshape/concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     442 self.verify_integrity = verify_integrity
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#     448 ndims = self._get_ndims(objs)
#
# File /data/wang/junh/envs/flex-moe/lib/python3.10/site-packages/pandas/core/reshape/concat.py:507, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     504     objs_list = list(objs)
#     506 if len(objs_list) == 0:
# --> 507     raise ValueError("No objects to concatenate")
#     509 if keys is None:
#     510     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_cc/"  # Replace with your output directory
missingInd = True              # Set to True if missing modality was used
modeltype = "TS_CXR_ECG"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)
df_all = df_all[~df_all['modality'].isin(['text'])]

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * CC Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("KL * CC")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %% [markdown]
# # TS CXR Text

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_mi/"  # Replace with your output directory
missingInd = False              # Set to True if missing modality was used
modeltype = "TS_CXR_Text"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)
df_all = df_all[~df_all['modality'].isin(['ecg'])]

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * MI Over Epochs (subset)")
plt.xlabel("Epoch")
plt.ylabel("KL * MI")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_mi/"  # Replace with your output directory
missingInd = True              # Set to True if missing modality was used
modeltype = "TS_CXR_Text"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)
df_all = df_all[~df_all['modality'].isin(['ecg'])]

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * MI Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("KL * MI")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_cc/"  # Replace with your output directory
missingInd = False              # Set to True if missing modality was used
modeltype = "TS_CXR_Text"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)
df_all = df_all[~df_all['modality'].isin(['ecg'])]

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * CC Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("KL * CC")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_cc/"  # Replace with your output directory
missingInd = True              # Set to True if missing modality was used
modeltype = "TS_CXR_Text"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)
df_all = df_all[~df_all['modality'].isin(['ecg'])]

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * CC Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("KL * CC")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %% [markdown]
# # TS ECG Text

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_mi/"  # Replace with your output directory
missingInd = False              # Set to True if missing modality was used
modeltype = "TS_ECG_Text"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)
df_all = df_all[~df_all['modality'].isin(['cxr'])]

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * MI Over Epochs (subset)")
plt.xlabel("Epoch")
plt.ylabel("KL * MI")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_mi/"  # Replace with your output directory
missingInd = True              # Set to True if missing modality was used
modeltype = "TS_ECG_Text"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)
df_all = df_all[~df_all['modality'].isin(['cxr'])]

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * MI Over Epochs (subset)")
plt.xlabel("Epoch")
plt.ylabel("KL * MI")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_cc/"  # Replace with your output directory
missingInd = False              # Set to True if missing modality was used
modeltype = "TS_ECG_Text"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)
df_all = df_all[~df_all['modality'].isin(['cxr'])]

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * CC Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("KL * CC")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()

# %%
# === Config ===
output_dir = "/data/wang/junh/results/Fuse_moe/all_los/multiclass/kl_cc/"  # Replace with your output directory
missingInd = True              # Set to True if missing modality was used
modeltype = "TS_ECG_Text"         # Replace manually as needed
weight_type = "kl_divergence"   # or "correlation_weight", "mutual_weight"

# === Collect CSVs and Concatenate ===
all_dfs = []
for epoch in range(8):  # Replace with the actual number of epochs
    if missingInd:
        fname = f"{output_dir}/Missing_{modeltype}_{epoch}_weights_log.csv"
    else:
        fname = f"{output_dir}/{modeltype}_{epoch}_weights_log.csv"
    
    if os.path.exists(fname):
        df = pd.read_csv(fname)
        df['epoch'] = epoch  # ensure epoch is int for sorting
        all_dfs.append(df)

# Combine all epochs
df_all = pd.concat(all_dfs, ignore_index=True)
df_all = df_all[~df_all['modality'].isin(['cxr'])]

# === Plotting ===
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_all, x="epoch", y=df_all['kl_divergence'], hue="modality", marker='o')

plt.title(f"KL * CC Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("KL * CC")
plt.legend(title="Modality")
plt.tight_layout()
plt.show()
